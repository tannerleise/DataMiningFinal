# %%
# Import packages
import numpy as np
import pandas as pd
import scipy.stats
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import itertools
import math
import os

# %% [markdown]
# <h1>Load Data</h1>

# %%
# Load data from files
df = pd.DataFrame()
path = 'data/'
for file in os.listdir(path):     # Concatinates all the csv's in the path folder and gives them labels based on year
    if file.lower().endswith(".csv"):
        file_name = path+"/"+file
        data = pd.read_csv(file_name) 
        data['Year'] = file[:file.index('.')]
        df = pd.concat([df, data]) # classified based on folder path

        
df = df[["SYSTEM", "DATE", "TIME", "SEVERITY", "ROAD_DESC", "VEHICLES", "CONTOUR", "CONDITION", "LIGHTING", "WEATHER", "CITY", "COUNTY", "LATITUDE", "LONGITUDE", "AGE_1", "AGE_2"]]
df
# Out:
#                SYSTEM        DATE    TIME SEVERITY             ROAD_DESC  \
# 0         CITY STREET    1/1/2008     0.0      PDO       AT INTERSECTION
# 1         CITY STREET    1/1/2008    12.0      PDO               UNKNOWN
# 2         CITY STREET    1/1/2008    13.0      INJ  INTERSECTION RELATED
# 3         CITY STREET    1/1/2008    29.0      PDO      NON-INTERSECTION
# 4         CITY STREET    1/1/2008    30.0      PDO      NON-INTERSECTION
# ...               ...         ...     ...      ...                   ...
# 112186  STATE HIGHWAY  12/31/2007  2342.0      INJ       AT INTERSECTION
# 112187    CITY STREET  12/31/2007  2343.0      PDO  INTERSECTION RELATED
# 112188     INTERSTATE  12/31/2007  2343.0      PDO      NON-INTERSECTION
# 112189    COUNTY ROAD  12/31/2007  2350.0      PDO  INTERSECTION RELATED
# 112190    CITY STREET  12/31/2007  2355.0      PDO       AT INTERSECTION
#
#         VEHICLES            CONTOUR                     CONDITION  \
# 0              1            UNKNOWN                       UNKNOWN
# 1              1            UNKNOWN                       UNKNOWN
# 2              2  STRAIGHT ON-LEVEL  WET W/VIS ICY ROAD TREATMENT
# 3              1     CURVE ON-GRADE                           DRY
# 4              2  STRAIGHT ON-LEVEL                         SNOWY
# ...          ...                ...                           ...
# 112186         2  STRAIGHT ON-LEVEL                           DRY
# 112187         2  STRAIGHT ON-LEVEL                           DRY
# 112188         1  STRAIGHT ON-LEVEL                         SNOWY
# 112189         1  STRAIGHT ON-GRADE                           ICY
# 112190         2  STRAIGHT ON-LEVEL                         SNOWY
#
#               LIGHTING  WEATHER      CITY     COUNTY   LATITUDE   LONGITUDE  \
# 0              UNKNOWN     NONE  FAIRPLAY       PARK   0.000000    0.000000
# 1              UNKNOWN  UNKNOWN    PUEBLO     PUEBLO   0.000000    0.000000
# 2         DARK-LIGHTED  UNKNOWN    DENVER     DENVER  39.738436 -104.982325
# 3       DARK-UNLIGHTED  UNKNOWN   DURANGO   LA PLATA   0.000000    0.000000
# 4         DARK-LIGHTED  UNKNOWN  LAKEWOOD  JEFFERSON  39.672860 -105.147678
# ...                ...      ...       ...        ...        ...         ...
# 112186    DARK-LIGHTED     NONE    PUEBLO     PUEBLO  38.219990 -104.643721
# 112187    DARK-LIGHTED     NONE    DENVER     DENVER  39.733690 -105.000150
# 112188  DARK-UNLIGHTED     NONE      VAIL      EAGLE  39.634044 -106.411499
# 112189    DARK-LIGHTED     NONE       NaN    DOUGLAS  39.559040 -104.896640
# 112190  DARK-UNLIGHTED     NONE    DENVER     DENVER  39.660220 -104.858990
#
#         AGE_1  AGE_2
# 0          50      0
# 1           0      0
# 2          59     42
# 3          18      0
# 4           0      0
# ...       ...    ...
# 112186     22     23
# 112187     19     26
# 112188     34      0
# 112189     18      0
# 112190     25     21
#
# [1449091 rows x 16 columns]

# %% [markdown]
# <h1>Function Definitions</h1>

# %%
# This function will get the nominal data points and count of a given column. Must be entered with quotations
def get_count(column):
    
    dict = {}
    for i in column:
        if not i in dict:
            dict[i] = 0

    for i in column:
        dict[i] = dict[i] + 1
    count = pd.DataFrame(columns=(column.name, "COUNT"))   

    for i in dict:
        data = {column.name:[i], "COUNT": [dict[i]]}
        temp = pd.DataFrame(data)
        count = pd.concat([count, temp])
    return count

# %%
# This is how we can access individual elements of the data frame
# for j in range(count_a.shape[0]):
#     print(count_a[col_a][j], count_a["COUNT"][j])

#This function will take 2 columns with nominal data points and will calculate the lift for all the data points
def lift(col_a, col_b, dataframe):
    col_a = pd.Series(col_a)
    col_b = pd.Series(col_b)
    lift_vals = []
    df_len = len(dataframe)
    count_a = get_count(col_a)
    count_b = get_count(col_b)
    combos = list(itertools.product(count_a[col_a.name], count_b[col_b.name]))
    
    count_a = count_a.rename({col_a.name: "NAME"}, axis=1)
    count_b = count_b.rename({col_b.name: "NAME"}, axis=1)
    count = pd.concat((count_a, count_b))
    
    dict = {}
    for (i, j) in count.iterrows():
        dict[j.NAME] = j.COUNT
    
    #Now that we got all the combinations, we gotta calculate the lift of each one
    for(i,j) in combos:
        a_and_b = len(df.loc[(df[col_a.name]== i) & (df[col_b.name]== j)])
        lift = (a_and_b/df_len)/((dict[i]/df_len)*(dict[j]/df_len))
        print("The lift of", i,"and",j, "=", lift)

#---------------------------------------------------------------------------------------------------------------
newframe = pre_processing2(df.LIGHTING, "LIGHTING", df.SEVERITY, "SEVERITY")
lift(newframe.LIGHTING, newframe.SEVERITY, newframe)
# Out:
# The lift of DARK-LIGHTED and INJ = 1.0083382249706225
# The lift of DARK-LIGHTED and PDO = 0.9958633456245762
# The lift of DARK-LIGHTED and FAT = 1.2455616476979654
# The lift of DARK-UNLIGHTED and INJ = 0.9502644977631927
# The lift of DARK-UNLIGHTED and PDO = 1.0078363196149338
# The lift of DARK-UNLIGHTED and FAT = 2.41290114058314
# The lift of DAYLIGHT and INJ = 1.0061998418941558
# The lift of DAYLIGHT and PDO = 0.9995331061019059
# The lift of DAYLIGHT and FAT = 0.7367211652057148
# The lift of DAWN OR DUSK and INJ = 0.9782549232647272
# The lift of DAWN OR DUSK and PDO = 1.0053604434083223
# The lift of DAWN OR DUSK and FAT = 1.2871664827487923

# %%
# Pass in the data frame and an array of the column names you want to convert
def create_labels(df, columns):
    for i in columns:
        labels = LabelEncoder().fit_transform(df[i])
        df[i] = labels
    return df

# %%
#In the case of our chi squared, c = 2, r = 2, therefore d = 1
#Somethings gotta be wrong with my logic here, according to this everything's correlated >:(
def chi_squared(col_a, col_b, dataframe):
    N = len(dataframe)
    col_a = pd.Series(col_a)
    col_b = pd.Series(col_b)
    count_a = get_count(col_a)
    count_b = get_count(col_b)
    combos = list(itertools.product(count_a[col_a.name], count_b[col_b.name]))
    
    count_a = count_a.rename({col_a.name: "NAME"}, axis=1)
    count_b = count_b.rename({col_b.name: "NAME"}, axis=1)
    count = pd.concat((count_a, count_b))
    
    dict = {}
    for (i, j) in count.iterrows():
        dict[j.NAME] = j.COUNT
            
    for(i,j) in combos:
        # This gets us all of actual values between 2 nominal sets of data
        a_and_b = len(df.loc[(df[col_a.name]== i) & (df[col_b.name]== j)])
        a_and_notb = len(df.loc[(df[col_a.name]== i) & (df[col_b.name]!= j)])
        nota_and_b = len(df.loc[(df[col_a.name]!= i) & (df[col_b.name]== j)])
        nota_and_notb = len(df.loc[(df[col_a.name]!= i) & (df[col_b.name]!= j)])
        
        # This gets us all of the expected values between 2 nominal sets of data
        e_a_and_b = (dict[i]*dict[j])/len(df)
        e_a_and_notb = (dict[i]*(N-dict[j]))/len(df)
        e_nota_and_b = ((N-dict[i])*dict[j])/len(df)
        e_nota_and_notb = ((N-dict[i])*(N-dict[j]))/len(df)
        
        #plugging it all into chi squared
        chi_a_b = pow((a_and_b - e_a_and_b),2)/e_a_and_b
        chi_a_notb = pow((a_and_notb - e_a_and_notb),2)/e_a_and_notb
        chi_nota_b = pow((nota_and_b - e_nota_and_b),2)/e_nota_and_b
        chi_nota_notb = pow((nota_and_notb - e_nota_and_notb),2)/e_nota_and_notb
        
        ans = chi_a_b + chi_a_notb + chi_nota_b + chi_nota_notb
        
        corr = check_correlation(ans,.001)
        
        print("Chi squared of ",i,"and ",j, "= ", ans, "which indicates these are ", corr)

#-----------------------------------------------------------------------------------------------------------        
newframe = pre_processing2(df.LIGHTING, "LIGHTING", df.SEVERITY, "SEVERITY")
print(chi_squared(newframe.LIGHTING, newframe.SEVERITY, newframe))
# Out:
# Chi squared of  DARK-LIGHTED and  INJ =  97.10617962990213 which indicates these are  correlated
# Chi squared of  DARK-LIGHTED and  PDO =  106.81577605852266 which indicates these are  correlated
# Chi squared of  DARK-LIGHTED and  FAT =  160.89308710714295 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  INJ =  196.5644611790934 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  PDO =  109.82237987378788 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  FAT =  1413.0665678706482 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  INJ =  204.42090099256654 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  PDO =  145.12631619095507 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  FAT =  1149.226734577513 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  INJ =  93.94420389508915 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  PDO =  89.87000224784458 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  FAT =  109.63294624404456 which indicates these are  correlated
# None

# %%
#This function assumes d = 1, and tells if there is a correlation or not according to the critical values of the Chi Squared Distribution

def check_correlation(value, prob):
    if prob == .05:
        if value > 3.841:
            return "correlated"
        else:
            return "not correlated"
    elif prob == .01:
        if value > 6.635:
            return "correlated"
        else:
            return "not correlated"
    elif prob == .001:
        if value > 10.828:
            return "correlated"
        else:
            return "not correlated"
    else:
        print("Enter a probability of .05, .01, or .001")
        return

# %% [markdown]
# <h1>Pre Processing</h1>

# %%
# Returns a data frame use .squeeze() to turn into a Series
# .name can only be used on a Series
def pre_processing(data, name):
    # remove all 0, null, and UNKONW rows
    data = data.to_frame()
    
#     print(data[data[name] == "UNKNOWN"])
    
    if (data[name].dtypes == object):
        data = data[data[name] != "UNKNOWN"]
    else:
        data = data[data[name] != 0]
        
    data = data.dropna()
    return data

# %%
# Returns a dataframe that contains the 2 entered names. It removes a row if one of the columns contains
# 0, null, or UNKNOWN
def pre_processing2(data1, name1,  data2, name2):
    data = data1.to_frame()
    data[name2] = data2
    
    if (data[name1].dtypes == object) or (data[name2].dtypes == object):
        data = data[(data[[name1,name2]] != "UNKNOWN").all(axis=1)]
    else:
        data = data[(data[[name1,name2]] != 0).all(axis=1)]
        
    data = data.dropna()
    
    return data

# %%
# pre_processing(df.SEVERITY, "SEVERITY").squeeze()
data = pre_processing2(df.LIGHTING, "LIGHTING", df.SEVERITY, "SEVERITY")
# Out:
# 2           DARK-LIGHTED
# 3         DARK-UNLIGHTED
# 4           DARK-LIGHTED
# 5           DARK-LIGHTED
# 6           DARK-LIGHTED
#                ...
# 112186      DARK-LIGHTED
# 112187      DARK-LIGHTED
# 112188    DARK-UNLIGHTED
# 112189      DARK-LIGHTED
# 112190    DARK-UNLIGHTED
# Name: LIGHTING, Length: 1443640, dtype: object

# %% [markdown]
# <h1>Hypothesis</h1>

# %% [markdown]
# <h3>Weather Conditions: Wet, Icy, Snowy, and Dark road conditions show an increase
# in accidents/severity</h3>

# %%
newframe = pre_processing2(df.WEATHER, "WEATHER",df.SEVERITY, "SEVERITY")
lift(newframe.WEATHER, newframe.SEVERITY, newframe)
chi_squared(newframe.WEATHER, newframe.SEVERITY, newframe)
# Out:
# The lift of NONE and PDO = 0.9930095899358082
# The lift of NONE and INJ = 1.0199469612367908
# The lift of NONE and FAT = 1.0677330273212862
# The lift of WIND and PDO = 0.9568740551639691
# The lift of WIND and INJ = 1.11373617121853
# The lift of WIND and FAT = 1.848202603229225
# The lift of RAIN and PDO = 0.9969170555732916
# The lift of RAIN and INJ = 1.0156792752906552
# The lift of RAIN and FAT = 0.7121879402296735
# The lift of SNOW/SLEET/HAIL and PDO = 1.0708853452328773
# The lift of SNOW/SLEET/HAIL and INJ = 0.7950367443835328
# The lift of SNOW/SLEET/HAIL and FAT = 0.43750377910038907
# The lift of DUST and PDO = 0.861901716908675
# The lift of DUST and INJ = 1.4073482200971188
# The lift of DUST and FAT = 1.7247030502219918
# The lift of FOG and PDO = 0.9795453458630856
# The lift of FOG and INJ = 1.0510410362752658
# The lift of FOG and FAT = 1.5363564049433178
# Chi squared of  NONE and  PDO =  561361.7775487015 which indicates these are  correlated
# Chi squared of  NONE and  INJ =  560414.4611499908 which indicates these are  correlated
# Chi squared of  NONE and  FAT =  561830.2850672596 which indicates these are  correlated
# Chi squared of  WIND and  PDO =  216110.4114994542 which indicates these are  correlated
# Chi squared of  WIND and  INJ =  216039.53572013462 which indicates these are  correlated
# Chi squared of  WIND and  FAT =  216358.03863682525 which indicates these are  correlated
# Chi squared of  RAIN and  PDO =  219001.61203096499 which indicates these are  correlated
# Chi squared of  RAIN and  INJ =  218958.68925841234 which indicates these are  correlated
# Chi squared of  RAIN and  FAT =  219249.40425728695 which indicates these are  correlated
# Chi squared of  SNOW/SLEET/HAIL and  PDO =  223969.92452060155 which indicates these are  correlated
# Chi squared of  SNOW/SLEET/HAIL and  INJ =  223806.40321205376 which indicates these are  correlated
# Chi squared of  SNOW/SLEET/HAIL and  FAT =  222360.64004690162 which indicates these are  correlated
# Chi squared of  DUST and  PDO =  215454.48865657276 which indicates these are  correlated
# Chi squared of  DUST and  INJ =  215407.43095090892 which indicates these are  correlated
# Chi squared of  DUST and  FAT =  215690.4151082296 which indicates these are  correlated
# Chi squared of  FOG and  PDO =  215675.8567345367 which indicates these are  correlated
# Chi squared of  FOG and  INJ =  215626.79844133047 which indicates these are  correlated
# Chi squared of  FOG and  FAT =  215940.48718225537 which indicates these are  correlated

# %% [markdown]
# <h3>Lighting: Poor Lighting will show a correlation to fatal accidents</h3>

# %%
# lighting = pre_processing(df.LIGHTING, "LIGHTING").squeeze()
# severity = pre_processing(df.SEVERITY, "SEVERITY").squeeze()
newframe = pre_processing2(df.LIGHTING, "LIGHTING",df.SEVERITY, "SEVERITY")
lift(newframe.LIGHTING, newframe.SEVERITY, newframe)
chi_squared(newframe.LIGHTING, newframe.SEVERITY, newframe)
# Out:
# The lift of DARK-LIGHTED and INJ = 1.0083382249706225
# The lift of DARK-LIGHTED and PDO = 0.9958633456245762
# The lift of DARK-LIGHTED and FAT = 1.2455616476979654
# The lift of DARK-UNLIGHTED and INJ = 0.9502644977631927
# The lift of DARK-UNLIGHTED and PDO = 1.0078363196149338
# The lift of DARK-UNLIGHTED and FAT = 2.41290114058314
# The lift of DAYLIGHT and INJ = 1.0061998418941558
# The lift of DAYLIGHT and PDO = 0.9995331061019059
# The lift of DAYLIGHT and FAT = 0.7367211652057148
# The lift of DAWN OR DUSK and INJ = 0.9782549232647272
# The lift of DAWN OR DUSK and PDO = 1.0053604434083223
# The lift of DAWN OR DUSK and FAT = 1.2871664827487923
# Chi squared of  DARK-LIGHTED and  INJ =  97.10617962990213 which indicates these are  correlated
# Chi squared of  DARK-LIGHTED and  PDO =  106.81577605852266 which indicates these are  correlated
# Chi squared of  DARK-LIGHTED and  FAT =  160.89308710714295 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  INJ =  196.5644611790934 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  PDO =  109.82237987378788 which indicates these are  correlated
# Chi squared of  DARK-UNLIGHTED and  FAT =  1413.0665678706482 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  INJ =  204.42090099256654 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  PDO =  145.12631619095507 which indicates these are  correlated
# Chi squared of  DAYLIGHT and  FAT =  1149.226734577513 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  INJ =  93.94420389508915 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  PDO =  89.87000224784458 which indicates these are  correlated
# Chi squared of  DAWN OR DUSK and  FAT =  109.63294624404456 which indicates these are  correlated

# %% [markdown]
# <h3>Road Conditions: Rough road conditions show an increase in accidents</h3>

# %%
# road = pre_processing(df.ROAD_DESC, "ROAD_DESC").squeeze()
# cont = pre_processing(df.CONTOUR, "CONTOUR").squeeze()
newframe = pre_processing2(df.ROAD_DESC, "ROAD_DESC",df.SEVERITY, "SEVERITY")
lift(newframe.ROAD_DESC, newframe.SEVERITY, newframe)
chi_squared(newframe.ROAD_DESC, newframe.SEVERITY, newframe)
# Out:
# The lift of AT INTERSECTION and PDO = 0.9451966582168044
# The lift of AT INTERSECTION and INJ = 1.1742252380055493
# The lift of AT INTERSECTION and FAT = 0.7462292533934156
# The lift of INTERSECTION RELATED and PDO = 1.017089778001948
# The lift of INTERSECTION RELATED and INJ = 0.9584872339478292
# The lift of INTERSECTION RELATED and FAT = 0.36923658743835513
# The lift of NON-INTERSECTION and PDO = 1.0234690915073053
# The lift of NON-INTERSECTION and INJ = 0.9194044311393419
# The lift of NON-INTERSECTION and FAT = 1.4401601985969
# The lift of AT DRIVEWAY ACCESS and PDO = 1.0315422989790621
# The lift of AT DRIVEWAY ACCESS and INJ = 0.91174857792152
# The lift of AT DRIVEWAY ACCESS and FAT = 0.48006239290136915
# The lift of RAMP and PDO = 1.0212248522792429
# The lift of RAMP and INJ = 0.9387040196298474
# The lift of RAMP and FAT = 0.7560027977585895
# The lift of ROUNDABOUT and PDO = 1.1717300100585375
# The lift of ROUNDABOUT and INJ = 0.4859170129414694
# The lift of ROUNDABOUT and FAT = 0.03041009985923006
# The lift of IN ALLEY and PDO = 1.1470847995263325
# The lift of IN ALLEY and INJ = 0.5590247681075173
# The lift of IN ALLEY and FAT = 0.20661060720526764
# The lift of PARKING LOT and PDO = 1.2332293832654033
# The lift of PARKING LOT and INJ = 0.29442232772429094
# The lift of PARKING LOT and FAT = 0.09265248806236338
# Chi squared of  AT INTERSECTION and  PDO =  6165.3007889068485 which indicates these are  correlated
# Chi squared of  AT INTERSECTION and  INJ =  6580.615160296487 which indicates these are  correlated
# Chi squared of  AT INTERSECTION and  FAT =  192.16653541951163 which indicates these are  correlated
# Chi squared of  INTERSECTION RELATED and  PDO =  189.5642148115095 which indicates these are  correlated
# Chi squared of  INTERSECTION RELATED and  INJ =  118.59248936650272 which indicates these are  correlated
# Chi squared of  INTERSECTION RELATED and  FAT =  374.9153675906114 which indicates these are  correlated
# Chi squared of  NON-INTERSECTION and  PDO =  2119.235066186894 which indicates these are  correlated
# Chi squared of  NON-INTERSECTION and  INJ =  2641.49137022592 which indicates these are  correlated
# Chi squared of  NON-INTERSECTION and  FAT =  1090.190578960442 which indicates these are  correlated
# Chi squared of  AT DRIVEWAY ACCESS and  PDO =  255.99343075723255 which indicates these are  correlated
# Chi squared of  AT DRIVEWAY ACCESS and  INJ =  211.91281533026492 which indicates these are  correlated
# Chi squared of  AT DRIVEWAY ACCESS and  FAT =  102.02780493312126 which indicates these are  correlated
# Chi squared of  RAMP and  PDO =  41.83753716536779 which indicates these are  correlated
# Chi squared of  RAMP and  INJ =  37.04477286877793 which indicates these are  correlated
# Chi squared of  RAMP and  FAT =  9.323889514838603 which indicates these are  not correlated
# Chi squared of  ROUNDABOUT and  PDO =  676.7773491794602 which indicates these are  correlated
# Chi squared of  ROUNDABOUT and  INJ =  640.7200081873846 which indicates these are  correlated
# Chi squared of  ROUNDABOUT and  FAT =  32.793598513546115 which indicates these are  correlated
# Chi squared of  IN ALLEY and  PDO =  511.91952235297697 which indicates these are  correlated
# Chi squared of  IN ALLEY and  INJ =  486.1367245765581 which indicates these are  correlated
# Chi squared of  IN ALLEY and  FAT =  23.117145394984863 which indicates these are  correlated
# Chi squared of  PARKING LOT and  PDO =  409.006351011037 which indicates these are  correlated
# Chi squared of  PARKING LOT and  INJ =  395.4599539417656 which indicates these are  correlated
# Chi squared of  PARKING LOT and  FAT =  10.53202367345021 which indicates these are  not correlated

# %% [markdown]
# <h3>Contour: A harsher contour to the road will be correlated with higher fatalities</h3>

# %%
newframe = pre_processing2(df.CONTOUR, "CONTOUR",df.SEVERITY, "SEVERITY")
lift(newframe.CONTOUR, newframe.SEVERITY, newframe)
chi_squared(newframe.CONTOUR, newframe.SEVERITY, newframe)
# Out:
# The lift of STRAIGHT ON-LEVEL and INJ = 0.9865068542707448
# The lift of STRAIGHT ON-LEVEL and PDO = 1.0055891728831923
# The lift of STRAIGHT ON-LEVEL and FAT = 0.7897209941593247
# The lift of CURVE ON-GRADE and INJ = 1.124256433387627
# The lift of CURVE ON-GRADE and PDO = 0.9504459879336999
# The lift of CURVE ON-GRADE and FAT = 2.6082601176759437
# The lift of STRAIGHT ON-GRADE and INJ = 0.991278083234747
# The lift of STRAIGHT ON-GRADE and PDO = 1.0036492389098128
# The lift of STRAIGHT ON-GRADE and FAT = 0.8578382236917824
# The lift of CURVE ON-LEVEL and INJ = 1.038308408748852
# The lift of CURVE ON-LEVEL and PDO = 0.9809101163643315
# The lift of CURVE ON-LEVEL and FAT = 2.14883851219767
# The lift of HILLCREST and INJ = 1.077331315368525
# The lift of HILLCREST and PDO = 0.9758405523946292
# The lift of HILLCREST and FAT = 0.8565858964430374
# Chi squared of  STRAIGHT ON-LEVEL and  INJ =  168.3894305910089 which indicates these are  correlated
# Chi squared of  STRAIGHT ON-LEVEL and  PDO =  257.9814230971266 which indicates these are  correlated
# Chi squared of  STRAIGHT ON-LEVEL and  FAT =  528.3088078709742 which indicates these are  correlated
# Chi squared of  CURVE ON-GRADE and  INJ =  546.5372728887253 which indicates these are  correlated
# Chi squared of  CURVE ON-GRADE and  PDO =  809.5783492744472 which indicates these are  correlated
# Chi squared of  CURVE ON-GRADE and  FAT =  1217.9125896676771 which indicates these are  correlated
# Chi squared of  STRAIGHT ON-GRADE and  INJ =  32.6870182490463 which indicates these are  correlated
# Chi squared of  STRAIGHT ON-GRADE and  PDO =  39.341324175659565 which indicates these are  correlated
# Chi squared of  STRAIGHT ON-GRADE and  FAT =  62.22000838477513 which indicates these are  correlated
# Chi squared of  CURVE ON-LEVEL and  INJ =  61.13706842075343 which indicates these are  correlated
# Chi squared of  CURVE ON-LEVEL and  PDO =  113.02108493946741 which indicates these are  correlated
# Chi squared of  CURVE ON-LEVEL and  FAT =  491.2535159267116 which indicates these are  correlated
# Chi squared of  HILLCREST and  INJ =  33.148707721293384 which indicates these are  correlated
# Chi squared of  HILLCREST and  PDO =  32.28722769514926 which indicates these are  correlated
# Chi squared of  HILLCREST and  FAT =  22.00785131615654 which indicates these are  correlated

# %% [markdown]
# <h3>Age: is there a correlation between age and accidents</h3>

# %% [markdown]
# <h3>System: type of road/speed limit will be correlated with severity of accident</h3>

# %%
newframe = pre_processing2(df.SYSTEM, "SYSTEM",df.SEVERITY, "SEVERITY")

lift(newframe.SYSTEM, newframe.SEVERITY, newframe)
chi_squared(newframe.SYSTEM, newframe.SEVERITY, newframe)
# Out:
# The lift of CITY STREET and PDO = 1.030666779219851
# The lift of CITY STREET and INJ = 0.9140406079908453
# The lift of CITY STREET and FAT = 0.5017380586883238
# The lift of COUNTY ROAD and PDO = 0.9306355556239375
# The lift of COUNTY ROAD and INJ = 1.1971514207986031
# The lift of COUNTY ROAD and FAT = 1.976197729570637
# The lift of STATE HIGHWAY and PDO = 0.9776203973897087
# The lift of STATE HIGHWAY and INJ = 1.062941385096866
# The lift of STATE HIGHWAY and FAT = 1.3519214212649315
# The lift of INTERSTATE and PDO = 0.9952312061084693
# The lift of INTERSTATE and INJ = 1.01147967636742
# The lift of INTERSTATE and FAT = 1.1820475258469834
# The lift of FRONTAGE ROAD and PDO = 0.9872722405508428
# The lift of FRONTAGE ROAD and INJ = 1.0225707924773964
# The lift of FRONTAGE ROAD and FAT = 1.9328888190537523
# The lift of UNKNOWN/PRIVATE and PDO = 1.3287988284563335
# The lift of UNKNOWN/PRIVATE and INJ = 0.0
# The lift of UNKNOWN/PRIVATE and FAT = 0.0
# Chi squared of  CITY STREET and  PDO =  3402.815211068571 which indicates these are  correlated
# Chi squared of  CITY STREET and  INJ =  2822.644899424844 which indicates these are  correlated
# Chi squared of  CITY STREET and  FAT =  1301.4085933093272 which indicates these are  correlated
# Chi squared of  COUNTY ROAD and  PDO =  1903.8701337276152 which indicates these are  correlated
# Chi squared of  COUNTY ROAD and  INJ =  1623.7937403924093 which indicates these are  correlated
# Chi squared of  COUNTY ROAD and  FAT =  546.305144334289 which indicates these are  correlated
# Chi squared of  STATE HIGHWAY and  PDO =  1099.7925357955223 which indicates these are  correlated
# Chi squared of  STATE HIGHWAY and  INJ =  918.4302116476174 which indicates these are  correlated
# Chi squared of  STATE HIGHWAY and  FAT =  393.9976565300197 which indicates these are  correlated
# Chi squared of  INTERSTATE and  PDO =  15.049445431512558 which indicates these are  correlated
# Chi squared of  INTERSTATE and  INJ =  9.207256115645286 which indicates these are  not correlated
# Chi squared of  INTERSTATE and  FAT =  31.773800151960426 which indicates these are  correlated
# Chi squared of  FRONTAGE ROAD and  PDO =  2.6243163008264374 which indicates these are  not correlated
# Chi squared of  FRONTAGE ROAD and  INJ =  0.871311446070394 which indicates these are  not correlated
# Chi squared of  FRONTAGE ROAD and  FAT =  20.425290536865727 which indicates these are  correlated
# Chi squared of  UNKNOWN/PRIVATE and  PDO =  0.3287990553565456 which indicates these are  not correlated
# Chi squared of  UNKNOWN/PRIVATE and  INJ =  0.32109798579787524 which indicates these are  not correlated
# Chi squared of  UNKNOWN/PRIVATE and  FAT =  0.0044062206802439555 which indicates these are  not correlated

# %% [markdown]
# <h3>Road Conditions: Rough road conditions show an increase in accidents</h3>

# %%
newframe = pre_processing2(df.CONDITION, "CONDITION",df.SEVERITY, "SEVERITY")

lift(newframe.CONDITION, newframe.SEVERITY, newframe)
chi_squared(newframe.CONDITION, newframe.SEVERITY, newframe)
# Out:
# The lift of WET W/VIS ICY ROAD TREATMENT and INJ = 1.0634216824319558
# The lift of WET W/VIS ICY ROAD TREATMENT and PDO = 0.9785061140287686
# The lift of WET W/VIS ICY ROAD TREATMENT and FAT = 1.1660914802454145
# The lift of DRY and INJ = 1.0358749262734535
# The lift of DRY and PDO = 0.9878404831877825
# The lift of DRY and FAT = 1.0941811170873623
# The lift of SNOWY and INJ = 0.6539584431708662
# The lift of SNOWY and PDO = 1.1157411570465967
# The lift of SNOWY and FAT = 0.35597171062967536
# The lift of ICY and INJ = 0.7649403916607098
# The lift of ICY and PDO = 1.0784231159199151
# The lift of ICY and FAT = 0.5963198237731716
# The lift of SLUSHY and INJ = 0.863551907637802
# The lift of SLUSHY and PDO = 1.0464054096646553
# The lift of SLUSHY and FAT = 0.6148762795666357
# The lift of SNOWY W/VIS ICY ROAD TREATMENT and INJ = 0.7027311611290573
# The lift of SNOWY W/VIS ICY ROAD TREATMENT and PDO = 1.1007285649361929
# The lift of SNOWY W/VIS ICY ROAD TREATMENT and FAT = 0.22443044926706357
# The lift of DRY W/VIS ICY ROAD TREATMENT and INJ = 1.2022359746645106
# The lift of DRY W/VIS ICY ROAD TREATMENT and PDO = 0.9326563331557067
# The lift of DRY W/VIS ICY ROAD TREATMENT and FAT = 1.3253484184470274
# The lift of ICY W/VIS ICY ROAD TREATMENT and INJ = 0.9368463830329635
# The lift of ICY W/VIS ICY ROAD TREATMENT and PDO = 1.0214051732021456
# The lift of ICY W/VIS ICY ROAD TREATMENT and FAT = 0.8342454415402905
# The lift of WET and INJ = 0.9928474932102133
# The lift of WET and PDO = 1.00418278869764
# The lift of WET and FAT = 0.680617768576905
# The lift of SLUSHY W/VIS ICY ROAD TREATMENT and INJ = 0.8874532745517028
# The lift of SLUSHY W/VIS ICY ROAD TREATMENT and PDO = 1.0402023103432017
# The lift of SLUSHY W/VIS ICY ROAD TREATMENT and FAT = 0.35315970928955487
# The lift of FOREIGN MATERIAL and INJ = 1.6543405948830148
# The lift of FOREIGN MATERIAL and PDO = 0.7870251251834427
# The lift of FOREIGN MATERIAL and FAT = 1.2120441222817522
# The lift of MUDDY and INJ = 0.9271307471469747
# The lift of MUDDY and PDO = 1.0227064370155057
# The lift of MUDDY and FAT = 1.149220090659057
# Chi squared of  WET W/VIS ICY ROAD TREATMENT and  INJ =  135.81471489635317 which indicates these are  correlated
# Chi squared of  WET W/VIS ICY ROAD TREATMENT and  PDO =  136.07649909270063 which indicates these are  correlated
# Chi squared of  WET W/VIS ICY ROAD TREATMENT and  FAT =  132.75732297925904 which indicates these are  correlated
# Chi squared of  DRY and  INJ =  3072.843409144294 which indicates these are  correlated
# Chi squared of  DRY and  PDO =  3305.8121710919468 which indicates these are  correlated
# Chi squared of  DRY and  FAT =  536.8746727404491 which indicates these are  correlated
# Chi squared of  SNOWY and  INJ =  2272.786616588418 which indicates these are  correlated
# Chi squared of  SNOWY and  PDO =  2391.618994836011 which indicates these are  correlated
# Chi squared of  SNOWY and  FAT =  235.40047202156796 which indicates these are  correlated
# Chi squared of  ICY and  INJ =  1759.257866524098 which indicates these are  correlated
# Chi squared of  ICY and  PDO =  1840.8231660102672 which indicates these are  correlated
# Chi squared of  ICY and  FAT =  200.2119258621595 which indicates these are  correlated
# Chi squared of  SLUSHY and  INJ =  210.60602154002285 which indicates these are  correlated
# Chi squared of  SLUSHY and  PDO =  217.71905637606588 which indicates these are  correlated
# Chi squared of  SLUSHY and  FAT =  141.2565340611525 which indicates these are  correlated
# Chi squared of  SNOWY W/VIS ICY ROAD TREATMENT and  INJ =  277.243654572819 which indicates these are  correlated
# Chi squared of  SNOWY W/VIS ICY ROAD TREATMENT and  PDO =  289.3045107251807 which indicates these are  correlated
# Chi squared of  SNOWY W/VIS ICY ROAD TREATMENT and  FAT =  146.07619747712974 which indicates these are  correlated
# Chi squared of  DRY W/VIS ICY ROAD TREATMENT and  INJ =  172.61786393730506 which indicates these are  correlated
# Chi squared of  DRY W/VIS ICY ROAD TREATMENT and  PDO =  174.4990020726723 which indicates these are  correlated
# Chi squared of  DRY W/VIS ICY ROAD TREATMENT and  FAT =  133.96003546940852 which indicates these are  correlated
# Chi squared of  ICY W/VIS ICY ROAD TREATMENT and  INJ =  139.21542785017328 which indicates these are  correlated
# Chi squared of  ICY W/VIS ICY ROAD TREATMENT and  PDO =  139.7610476535986 which indicates these are  correlated
# Chi squared of  ICY W/VIS ICY ROAD TREATMENT and  FAT =  133.14698004092529 which indicates these are  correlated
# Chi squared of  WET and  INJ =  137.00944519652424 which indicates these are  correlated
# Chi squared of  WET and  PDO =  140.43292422139496 which indicates these are  correlated
# Chi squared of  WET and  FAT =  182.81089323987533 which indicates these are  correlated
# Chi squared of  SLUSHY W/VIS ICY ROAD TREATMENT and  INJ =  138.55761673077393 which indicates these are  correlated
# Chi squared of  SLUSHY W/VIS ICY ROAD TREATMENT and  PDO =  139.67840017340885 which indicates these are  correlated
# Chi squared of  SLUSHY W/VIS ICY ROAD TREATMENT and  FAT =  134.89430525130913 which indicates these are  correlated
# Chi squared of  FOREIGN MATERIAL and  INJ =  289.91674377778077 which indicates these are  correlated
# Chi squared of  FOREIGN MATERIAL and  PDO =  289.9389613635247 which indicates these are  correlated
# Chi squared of  FOREIGN MATERIAL and  FAT =  132.75098897454214 which indicates these are  correlated
# Chi squared of  MUDDY and  INJ =  136.03602389052946 which indicates these are  correlated
# Chi squared of  MUDDY and  PDO =  135.872303103994 which indicates these are  correlated
# Chi squared of  MUDDY and  FAT =  132.69330041287472 which indicates these are  correlated

# %% [markdown]
# <h3>City: Does the city your in have a correlation with likelyhood of accident</h3>

# %%
lift(df.CITY, df.SEVERITY)
chi_squared(df.CITY, df.SEVERITY)
# Out:
# The lift of FAIRPLAY and PDO = 1.0362192698971406
# The lift of FAIRPLAY and INJ = 0.8304124636046625
# The lift of FAIRPLAY and FAT = 4.18260589713283
# The lift of PUEBLO and PDO = 0.9595259191422915
# The lift of PUEBLO and INJ = 1.1296584213537602
# The lift of PUEBLO and FAT = 0.7595523620844016
# The lift of DENVER and PDO = 1.058240573852441
# The lift of DENVER and INJ = 0.8287800377606337
# The lift of DENVER and FAT = 0.4953517317696174
# The lift of DURANGO and PDO = 1.1135472028332698
# The lift of DURANGO and INJ = 0.6610046664072418
# The lift of DURANGO and FAT = 0.3031680029175943
# The lift of LAKEWOOD and PDO = 1.0228905518653593
# The lift of LAKEWOOD and INJ = 0.9339978476370828
# The lift of LAKEWOOD and FAT = 0.7300071139234586
# The lift of LONGMONT and PDO = 0.9759389096908075
# The lift of LONGMONT and INJ = 1.0828275480981076
# The lift of LONGMONT and FAT = 0.5385915366717636
# The lift of THORNTON and PDO = 1.0311235564784946
# The lift of THORNTON and INJ = 0.911539490195978
# The lift of THORNTON and FAT = 0.5619525091587161
# The lift of ARVADA and PDO = 1.0535749348561319
# The lift of ARVADA and INJ = 0.8423382358896847
# The lift of ARVADA and FAT = 0.5445436476559131
# The lift of COLORADO SPRINGS and PDO = 0.9426803178614266
# The lift of COLORADO SPRINGS and INJ = 1.1824623920754944
# The lift of COLORADO SPRINGS and FAT = 0.7237894097527254
# The lift of COMMERCE CITY and PDO = 1.0464177240359136
# The lift of COMMERCE CITY and INJ = 0.8537979683897013
# The lift of COMMERCE CITY and FAT = 1.137422936551125
# The lift of LA JUNTA and PDO = 1.0566476331790082
# The lift of LA JUNTA and INJ = 0.8330772331295945
# The lift of LA JUNTA and FAT = 0.5305322452918677
# The lift of nan and PDO = 0.0
# The lift of nan and INJ = 0.0
# The lift of nan and FAT = 0.0
# The lift of ASPEN and PDO = 1.2252733439240855
# The lift of ASPEN and INJ = 0.32054256749723514
# The lift of ASPEN and FAT = 0.0
# The lift of PUEBLO WEST and PDO = 0.9994711649196053
# The lift of PUEBLO WEST and INJ = 0.9722591825646414
# The lift of PUEBLO WEST and FAT = 2.6276890074206247
# The lift of AURORA and PDO = 0.8956200851960178
# The lift of AURORA and INJ = 1.3287478854513934
# The lift of AURORA and FAT = 0.6919630108955847
# The lift of WHEAT RIDGE and PDO = 1.035370922775291
# The lift of WHEAT RIDGE and INJ = 0.9020184465947211
# The lift of WHEAT RIDGE and FAT = 0.3608372941392523
# The lift of GREELEY and PDO = 1.0727837575715617
# The lift of GREELEY and INJ = 0.7814752436557302
# The lift of GREELEY and FAT = 0.6214088507949888
# The lift of CENTENNIAL and PDO = 1.0295339640735583
# The lift of CENTENNIAL and INJ = 0.9217404912579883
# The lift of CENTENNIAL and FAT = 0.2694606821224239
# The lift of BOULDER and PDO = 0.980194359426973
# The lift of BOULDER and INJ = 1.0746627299143654
# The lift of BOULDER and FAT = 0.26094851065481534
# The lift of BRECKENRIDGE and PDO = 1.2065317297761409
# The lift of BRECKENRIDGE and INJ = 0.37251446781368847
# The lift of BRECKENRIDGE and FAT = 0.33559370098452584
# The lift of SHERIDAN and PDO = 1.0545651109247545
# The lift of SHERIDAN and INJ = 0.8442718692294485
# The lift of SHERIDAN and FAT = 0.26754932088467037
# The lift of LOVELAND and PDO = 0.8744008396629539
# The lift of LOVELAND and INJ = 1.3951046632454671
# The lift of LOVELAND and FAT = 0.6555997164041967
# The lift of BRIGHTON and PDO = 1.1167692783128025
# The lift of BRIGHTON and INJ = 0.6370206657008888
# The lift of BRIGHTON and FAT = 1.0792530477995108
# The lift of FORT COLLINS and PDO = 1.0031343701476774
# The lift of FORT COLLINS and INJ = 1.0007997783879692
# The lift of FORT COLLINS and FAT = 0.4179954663005202
# The lift of LAMAR and PDO = 1.1054394812229327
# The lift of LAMAR and INJ = 0.683765766349777
# The lift of LAMAR and FAT = 0.4329573055911476
# The lift of LEADVILLE and PDO = 1.157806110996061
# The lift of LEADVILLE and INJ = 0.529439151390513
# The lift of LEADVILLE and FAT = 0.0
# The lift of MONTROSE and PDO = 1.0331686283332162
# The lift of MONTROSE and INJ = 0.9018657469891215
# The lift of MONTROSE and FAT = 0.7470955010012659
# The lift of DILLON and PDO = 1.1216476802939392
# The lift of DILLON and INJ = 0.6257515280532886
# The lift of DILLON and FAT = 0.8667377239305674
# The lift of NEW CASTLE and PDO = 1.1322863256564533
# The lift of NEW CASTLE and INJ = 0.6012117124064805
# The lift of NEW CASTLE and FAT = 0.4013239813270057
# The lift of GOLDEN and PDO = 1.063316639363073
# The lift of GOLDEN and INJ = 0.812181507141949
# The lift of GOLDEN and FAT = 0.544200588227369
# The lift of SNOWMASS VILLAGE and PDO = 1.1651062191537416
# The lift of SNOWMASS VILLAGE and INJ = 0.4949105110824361
# The lift of SNOWMASS VILLAGE and FAT = 0.660730496793447
# The lift of BERTHOUD and PDO = 0.9998963889066578
# The lift of BERTHOUD and INJ = 1.0056083256814186
# The lift of BERTHOUD and FAT = 0.7070472127597369
# The lift of LAFAYETTE and PDO = 0.9819685642931844
# The lift of LAFAYETTE and INJ = 1.067217407337192
# The lift of LAFAYETTE and FAT = 0.36909329888882647
# The lift of WESTMINSTER and PDO = 1.009070782701482
# The lift of WESTMINSTER and INJ = 0.9786747826748379
# The lift of WESTMINSTER and FAT = 0.6254455515721948
# The lift of PARKER and PDO = 1.1410959793031563
# The lift of PARKER and INJ = 0.5752719025595268
# The lift of PARKER and FAT = 0.32723517283051856
# The lift of FIRESTONE and PDO = 1.064195797327379
# The lift of FIRESTONE and INJ = 0.8080893270941699
# The lift of FIRESTONE and FAT = 0.6201088721266027
# The lift of GRAND JUNCTION and PDO = 1.0088066647704819
# The lift of GRAND JUNCTION and INJ = 0.974513842407261
# The lift of GRAND JUNCTION and FAT = 0.9012895068596071
# The lift of CRIPPLE CREEK and PDO = 1.0743479889646952
# The lift of CRIPPLE CREEK and INJ = 0.7528323436973023
# The lift of CRIPPLE CREEK and FAT = 1.940017203350972
# The lift of FORT MORGAN and PDO = 1.1386301284770732
# The lift of FORT MORGAN and INJ = 0.587583863143794
# The lift of FORT MORGAN and FAT = 0.06810637029989221
# The lift of TELLURIDE and PDO = 1.241101918687336
# The lift of TELLURIDE and INJ = 0.26563017699105707
# The lift of TELLURIDE and FAT = 0.3270473764616057
# The lift of CASTLE ROCK and PDO = 1.0869632065312003
# The lift of CASTLE ROCK and INJ = 0.7443253344157508
# The lift of CASTLE ROCK and FAT = 0.24723646571989066
# The lift of WINTER PARK and PDO = 1.1559067875791156
# The lift of WINTER PARK and INJ = 0.5276725362259772
# The lift of WINTER PARK and FAT = 0.42370264199579777
# The lift of SILVERTHORNE and PDO = 1.1019958155672003
# The lift of SILVERTHORNE and INJ = 0.6994888483436378
# The lift of SILVERTHORNE and FAT = 0.15257832757278394
# The lift of LONE TREE and PDO = 1.1147748805012891
# The lift of LONE TREE and INJ = 0.6558003232328065
# The lift of LONE TREE and FAT = 0.3809075738105557
# The lift of CORTEZ and PDO = 0.9778836448851186
# The lift of CORTEZ and INJ = 1.0599676375359237
# The lift of CORTEZ and FAT = 1.4715212648656875
# The lift of CENTER and PDO = 1.2013797627139453
# The lift of CENTER and INJ = 0.3945234805294878
# The lift of CENTER and FAT = 0.0
# The lift of ALAMOSA and PDO = 1.0823210418253983
# The lift of ALAMOSA and INJ = 0.7618103714642188
# The lift of ALAMOSA and FAT = 0.07483651391783953
# The lift of CARBONDALE and PDO = 1.0965291145391693
# The lift of CARBONDALE and INJ = 0.7135941544846175
# The lift of CARBONDALE and FAT = 0.3088780777692943
# The lift of ELIZABETH and PDO = 1.022835138255598
# The lift of ELIZABETH and INJ = 0.933615711432565
# The lift of ELIZABETH and FAT = 0.7606852771759929
# The lift of BLUE RIVER and PDO = 1.1350156659731183
# The lift of BLUE RIVER and INJ = 0.5657184908306762
# The lift of BLUE RIVER and FAT = 1.89960017828116
# The lift of CHERRY HILLS VILLAGE and PDO = 1.0571414812795463
# The lift of CHERRY HILLS VILLAGE and INJ = 0.8365586257044726
# The lift of CHERRY HILLS VILLAGE and FAT = 0.2529287338626788
# The lift of PAGOSA SPRINGS and PDO = 1.0192220404647145
# The lift of PAGOSA SPRINGS and INJ = 0.9437858172215908
# The lift of PAGOSA SPRINGS and FAT = 0.8170323347445849
# The lift of ENGLEWOOD and PDO = 1.0904497170553764
# The lift of ENGLEWOOD and INJ = 0.7292106563812788
# The lift of ENGLEWOOD and FAT = 0.48655714278279444
# The lift of FRISCO and PDO = 1.1608280128442061
# The lift of FRISCO and INJ = 0.520082535659559
# The lift of FRISCO and FAT = 0.0
# The lift of LITTLETON and PDO = 1.087913548067958
# The lift of LITTLETON and INJ = 0.7386103751059497
# The lift of LITTLETON and FAT = 0.40084281597492305
# The lift of GUNNISON and PDO = 1.100791153250043
# The lift of GUNNISON and INJ = 0.6770393906374031
# The lift of GUNNISON and FAT = 1.6030381251317805
# The lift of VAIL and PDO = 1.1851069509163212
# The lift of VAIL and INJ = 0.4304163227172458
# The lift of VAIL and FAT = 0.802930684726098
# The lift of EVANS and PDO = 1.0534562211273968
# The lift of EVANS and INJ = 0.8413568520313432
# The lift of EVANS and FAT = 0.6192818560956116
# The lift of GREENWOOD VILLAGE and PDO = 1.0572034595479025
# The lift of GREENWOOD VILLAGE and INJ = 0.8375285167577574
# The lift of GREENWOOD VILLAGE and FAT = 0.18856010191992265
# The lift of ERIE and PDO = 0.9854309044254287
# The lift of ERIE and INJ = 1.0523102987585662
# The lift of ERIE and FAT = 0.601060043226735
# The lift of CRAIG and PDO = 1.1309720365794074
# The lift of CRAIG and INJ = 0.6055903762926954
# The lift of CRAIG and FAT = 0.38418880010180767
# The lift of GLENDALE and PDO = 1.0420496596510378
# The lift of GLENDALE and INJ = 0.8862109295385727
# The lift of GLENDALE and FAT = 0.09092621515506152
# The lift of YUMA and PDO = 1.1886873873605976
# The lift of YUMA and INJ = 0.43382246668524344
# The lift of YUMA and FAT = 0.0
# The lift of STEAMBOAT SPRINGS and PDO = 1.1882755287480633
# The lift of STEAMBOAT SPRINGS and INJ = 0.43347115759528543
# The lift of STEAMBOAT SPRINGS and FAT = 0.09011742296649108
# The lift of FRASER and PDO = 1.0716119584325268
# The lift of FRASER and INJ = 0.7963192832807173
# The lift of FRASER and FAT = 0.0
# The lift of BROOMFIELD and PDO = 1.0614406002335828
# The lift of BROOMFIELD and INJ = 0.8197223782889383
# The lift of BROOMFIELD and FAT = 0.44823137628749826
# The lift of DELTA and PDO = 1.104587777324998
# The lift of DELTA and INJ = 0.6785288077906716
# The lift of DELTA and FAT = 0.8692164781458119
# The lift of HUDSON and PDO = 0.9799083743073447
# The lift of HUDSON and INJ = 1.040248528888587
# The lift of HUDSON and FAT = 2.2167133360817424
# The lift of BURLINGTON and PDO = 1.153297096396063
# The lift of BURLINGTON and INJ = 0.5434002656349549
# The lift of BURLINGTON and FAT = 0.0
# The lift of LOUISVILLE and PDO = 1.003008118907152
# The lift of LOUISVILLE and INJ = 0.996608234845428
# The lift of LOUISVILLE and FAT = 0.6718843074306353
# The lift of BUENA VISTA and PDO = 1.130550616146316
# The lift of BUENA VISTA and INJ = 0.6138294475288862
# The lift of BUENA VISTA and FAT = 0.0
# The lift of HIGHLANDS RANCH and PDO = 1.0365233491813575
# The lift of HIGHLANDS RANCH and INJ = 0.8909687219019515
# The lift of HIGHLANDS RANCH and FAT = 0.7753470115433305
# The lift of NORTHGLENN and PDO = 1.1193632042064066
# The lift of NORTHGLENN and INJ = 0.640202067042955
# The lift of NORTHGLENN and FAT = 0.4580074845684594
# The lift of MONTE VISTA and PDO = 1.0753999820995443
# The lift of MONTE VISTA and INJ = 0.775022372216233
# The lift of MONTE VISTA and FAT = 0.53012097998544
# The lift of ROMEO and PDO = 0.8542278182933573
# The lift of ROMEO and INJ = 1.4693986774822763
# The lift of ROMEO and FAT = 0.0
# The lift of WINDSOR and PDO = 1.0677929354227707
# The lift of WINDSOR and INJ = 0.7954061778073991
# The lift of WINDSOR and FAT = 0.7057338123645176
# The lift of STRATTON and PDO = 1.0847337375153743
# The lift of STRATTON and INJ = 0.6717251097061834
# The lift of STRATTON and FAT = 4.6520820692599845
# The lift of DACONO and PDO = 0.9877097337386027
# The lift of DACONO and INJ = 1.0316372875405793
# The lift of DACONO and FAT = 1.3555125157209467
# The lift of WOODLAND PARK and PDO = 1.0816436043591922
# The lift of WOODLAND PARK and INJ = 0.7547468321947798
# The lift of WOODLAND PARK and FAT = 0.5824016898153785
# The lift of EAGLE and PDO = 1.1838886681514247
# The lift of EAGLE and INJ = 0.4486805838238061
# The lift of EAGLE and FAT = 0.0
# The lift of EATON and PDO = 1.0949096729640193
# The lift of EATON and INJ = 0.7003091569277231
# The lift of EATON and FAT = 1.3227390022847534
# The lift of STERLING and PDO = 1.1373548635054818
# The lift of STERLING and INJ = 0.5777550544653716
# The lift of STERLING and FAT = 0.8314359442932736
# The lift of SALIDA and PDO = 1.1184427151444056
# The lift of SALIDA and INJ = 0.6421452414415297
# The lift of SALIDA and FAT = 0.5082542283026515
# The lift of FEDERAL HEIGHTS and PDO = 1.0404980517106528
# The lift of FEDERAL HEIGHTS and INJ = 0.8868723039349444
# The lift of FEDERAL HEIGHTS and FAT = 0.3204573871514609
# The lift of GARDEN CITY and PDO = 1.0035199485737936
# The lift of GARDEN CITY and INJ = 1.00715034352431
# The lift of GARDEN CITY and FAT = 0.0
# The lift of ESTES PARK and PDO = 1.1154799529850825
# The lift of ESTES PARK and INJ = 0.6536121207529857
# The lift of ESTES PARK and FAT = 0.3811906712269886
# The lift of PLATTEVILLE and PDO = 1.0179100459495685
# The lift of PLATTEVILLE and INJ = 0.9211928312668758
# The lift of PLATTEVILLE and FAT = 2.293856819056495
# The lift of GEORGETOWN and PDO = 0.9627823846899184
# The lift of GEORGETOWN and INJ = 1.1209664162349817
# The lift of GEORGETOWN and FAT = 0.6824910820171833
# The lift of FOUNTAIN and PDO = 0.9093636544873582
# The lift of FOUNTAIN and INJ = 1.2754926185837527
# The lift of FOUNTAIN and FAT = 1.2848754521530392
# The lift of GLENWOOD SPRINGS and PDO = 1.1276478745805905
# The lift of GLENWOOD SPRINGS and INJ = 0.6152011410701195
# The lift of GLENWOOD SPRINGS and FAT = 0.42195972697319056
# The lift of MONUMENT and PDO = 1.0240664918212616
# The lift of MONUMENT and INJ = 0.9242769840262929
# The lift of MONUMENT and FAT = 1.0668581344480772
# The lift of KERSEY and PDO = 0.9749543812186697
# The lift of KERSEY and INJ = 1.0606311133781414
# The lift of KERSEY and FAT = 1.9372693036295117
# The lift of BRUSH and PDO = 1.087541736197595
# The lift of BRUSH and INJ = 0.7411605244151735
# The lift of BRUSH and FAT = 0.3233362005584953
# The lift of RIFLE and PDO = 1.094956289527008
# The lift of RIFLE and INJ = 0.7159717085379325
# The lift of RIFLE and FAT = 0.4469647478308612
# The lift of SUPERIOR and PDO = 1.0552225990682647
# The lift of SUPERIOR and INJ = 0.8395020385321534
# The lift of SUPERIOR and FAT = 0.41902945109143236
# The lift of FREDERICK and PDO = 0.9713441728481971
# The lift of FREDERICK and INJ = 1.0987550344682284
# The lift of FREDERICK and FAT = 0.4443509188961778
# The lift of IDAHO SPRINGS and PDO = 1.1744813248377388
# The lift of IDAHO SPRINGS and INJ = 0.47780823285362145
# The lift of IDAHO SPRINGS and FAT = 0.0
# The lift of RANGELY and PDO = 1.1489613930261529
# The lift of RANGELY and INJ = 0.5568247619932836
# The lift of RANGELY and FAT = 0.0
# The lift of AVON and PDO = 1.1339602905595103
# The lift of AVON and INJ = 0.5960329180919309
# The lift of AVON and FAT = 0.4010886006927963
# The lift of FORT LUPTON and PDO = 1.0497585354509047
# The lift of FORT LUPTON and INJ = 0.8293315837199235
# The lift of FORT LUPTON and FAT = 1.919865424427899
# The lift of MEAD and PDO = 0.9422715552994644
# The lift of MEAD and INJ = 1.1784078401899862
# The lift of MEAD and FAT = 1.0185523744134906
# The lift of JOHNSTOWN and PDO = 0.9996889405686634
# The lift of JOHNSTOWN and INJ = 1.0026117577208322
# The lift of JOHNSTOWN and FAT = 0.9086580709290694
# The lift of CANON CITY and PDO = 1.081002690263853
# The lift of CANON CITY and INJ = 0.7593536789673507
# The lift of CANON CITY and FAT = 0.4371083823465756
# The lift of FRUITA and PDO = 1.1372796450836797
# The lift of FRUITA and INJ = 0.579668854793008
# The lift of FRUITA and FAT = 0.738306142165957
# The lift of BASALT and PDO = 1.1522742978978038
# The lift of BASALT and INJ = 0.5379597668606658
# The lift of BASALT and FAT = 0.4768870740454794
# The lift of MOUNTAIN VILLAGE and PDO = 1.176166530593106
# The lift of MOUNTAIN VILLAGE and INJ = 0.44479095102166194
# The lift of MOUNTAIN VILLAGE and FAT = 1.5402163607685082
# The lift of GYPSUM and PDO = 1.1073323570469447
# The lift of GYPSUM and INJ = 0.6781002785714504
# The lift of GYPSUM and FAT = 0.4221333729513689
# The lift of MT CRESTED BUTTE and PDO = 1.1829550546013698
# The lift of MT CRESTED BUTTE and INJ = 0.451571300884797
# The lift of MT CRESTED BUTTE and FAT = 0.0
# The lift of MANITOU SPRINGS and PDO = 1.124637463241357
# The lift of MANITOU SPRINGS and INJ = 0.6213014952374576
# The lift of MANITOU SPRINGS and FAT = 0.6004004075339926
# The lift of CRESTED BUTTE and PDO = 1.2057618998955617
# The lift of CRESTED BUTTE and INJ = 0.38095521268059007
# The lift of CRESTED BUTTE and FAT = 0.0
# The lift of TRINIDAD and PDO = 1.112084856433412
# The lift of TRINIDAD and INJ = 0.6657069716524852
# The lift of TRINIDAD and FAT = 0.2935004567301363
# The lift of MORRISON and PDO = 1.031203257499967
# The lift of MORRISON and INJ = 0.9000066899578941
# The lift of MORRISON and FAT = 1.187250111425725
# The lift of LARKSPUR and PDO = 1.1419364932046614
# The lift of LARKSPUR and INJ = 0.5785757292586462
# The lift of LARKSPUR and FAT = 0.0
# The lift of SILT and PDO = 1.138970424391143
# The lift of SILT and INJ = 0.5502429090146397
# The lift of SILT and FAT = 2.0785898607331843
# The lift of GRANBY and PDO = 1.1141467100133873
# The lift of GRANBY and INJ = 0.6487960314421742
# The lift of GRANBY and FAT = 0.8767385438220738
# The lift of CALHAN and PDO = 0.9686570899027477
# The lift of CALHAN and INJ = 1.1150950711360823
# The lift of CALHAN and FAT = 0.0
# The lift of PARACHUTE and PDO = 1.14107378620904
# The lift of PARACHUTE and INJ = 0.5812469006771995
# The lift of PARACHUTE and FAT = 0.0
# The lift of FLAGLER and PDO = 1.153956877343658
# The lift of FLAGLER and INJ = 0.54135740749347
# The lift of FLAGLER and FAT = 0.0
# The lift of MANASSA and PDO = 1.075694289702746
# The lift of MANASSA and INJ = 0.783679294657214
# The lift of MANASSA and FAT = 0.0
# The lift of EDGEWATER and PDO = 1.0106853280043313
# The lift of EDGEWATER and INJ = 0.9813298588132516
# The lift of EDGEWATER and FAT = 0.20137104363404523
# The lift of BAYFIELD and PDO = 1.1669579455033185
# The lift of BAYFIELD and INJ = 0.44835498107792526
# The lift of BAYFIELD and FAT = 2.9224618127402464
# The lift of WRAY and PDO = 1.2079989349603033
# The lift of WRAY and INJ = 0.37402875426821575
# The lift of WRAY and FAT = 0.0
# The lift of WALSENBURG and PDO = 1.0912374099968436
# The lift of WALSENBURG and INJ = 0.7295735294010836
# The lift of WALSENBURG and FAT = 0.3313256124909
# The lift of MILLIKEN and PDO = 1.0804026772203945
# The lift of MILLIKEN and INJ = 0.7541668711288341
# The lift of MILLIKEN and FAT = 0.8274120558756414
# The lift of LIMON and PDO = 1.0815804417667831
# The lift of LIMON and INJ = 0.7016663452163427
# The lift of LIMON and FAT = 3.5341398665696
# The lift of HOLYOKE and PDO = 1.1736106441110683
# The lift of HOLYOKE and INJ = 0.48050409307449615
# The lift of HOLYOKE and FAT = 0.0
# The lift of PEYTON and PDO = 0.9965991213422501
# The lift of PEYTON and INJ = 1.0285790742375933
# The lift of PEYTON and FAT = 0.0
# The lift of ORCHARD CITY and PDO = 0.9684466037902092
# The lift of ORCHARD CITY and INJ = 1.0634461614998847
# The lift of ORCHARD CITY and FAT = 2.8976951872085497
# The lift of MOFFAT and PDO = 0.5315195313825334
# The lift of MOFFAT and INJ = 2.0571581484751866
# The lift of MOFFAT and FAT = 22.795202139373924
# The lift of ROCKY FORD and PDO = 1.0210769944980245
# The lift of ROCKY FORD and INJ = 0.9383528396553482
# The lift of ROCKY FORD and FAT = 0.79983165401312
# The lift of PITKIN and PDO = 1.277691181208013
# The lift of PITKIN and INJ = 0.15824293449809126
# The lift of PITKIN and FAT = 0.0
# The lift of OAK CREEK and PDO = 1.085900117878294
# The lift of OAK CREEK and INJ = 0.7520793230984552
# The lift of OAK CREEK and FAT = 0.0
# The lift of BLACK HAWK and PDO = 1.0602489339914052
# The lift of BLACK HAWK and INJ = 0.8315022437406266
# The lift of BLACK HAWK and FAT = 0.0
# The lift of FRANKTOWN and PDO = 0.8858658856375556
# The lift of FRANKTOWN and INJ = 1.3714387656501243
# The lift of FRANKTOWN and FAT = 0.0
# The lift of LOCHBUIE and PDO = 1.0602489339914052
# The lift of LOCHBUIE and INJ = 0.7991060524260568
# The lift of LOCHBUIE and FAT = 1.7948978062499148
# The lift of FLORENCE and PDO = 1.1380915891871375
# The lift of FLORENCE and INJ = 0.5523850583868557
# The lift of FLORENCE and FAT = 2.110666864756845
# The lift of SWINK and PDO = 1.0530103923616227
# The lift of SWINK and INJ = 0.7762860937642213
# The lift of SWINK and FAT = 4.300981535730928
# The lift of AULT and PDO = 1.078729676237614
# The lift of AULT and INJ = 0.7742809267323579
# The lift of AULT and FAT = 0.0
# The lift of MINTURN and PDO = 1.0806496496482232
# The lift of MINTURN and INJ = 0.7435511380030795
# The lift of MINTURN and FAT = 1.3732049481550557
# The lift of AKRON and PDO = 1.180237468753141
# The lift of AKRON and INJ = 0.45998567295097337
# The lift of AKRON and FAT = 0.0
# The lift of LAKE CITY and PDO = 1.016140280584255
# The lift of LAKE CITY and INJ = 0.9075697713861117
# The lift of LAKE CITY and FAT = 3.352235608731459
# The lift of WESTCLIFFE and PDO = 1.0892728593783678
# The lift of WESTCLIFFE and INJ = 0.7239784041844004
# The lift of WESTCLIFFE and FAT = 0.9783348557671212
# The lift of MANZANOLA and PDO = 0.99659912134225
# The lift of MANZANOLA and INJ = 1.0285790742375933
# The lift of MANZANOLA and FAT = 0.0
# The lift of ELBERT and PDO = 0.9222260525853658
# The lift of ELBERT and INJ = 1.2588579714549648
# The lift of ELBERT and FAT = 0.0
# The lift of CENTRAL CITY and PDO = 1.0608666396122772
# The lift of CENTRAL CITY and INJ = 0.8183789909465319
# The lift of CENTRAL CITY and FAT = 0.621122674097382
# The lift of SILVER CLIFF and PDO = 1.098473698190569
# The lift of SILVER CLIFF and INJ = 0.7131481581380648
# The lift of SILVER CLIFF and FAT = 0.0
# The lift of KIOWA and PDO = 0.9815750139853318
# The lift of KIOWA and INJ = 1.0337478133041138
# The lift of KIOWA and FAT = 2.290975089384314
# The lift of GREEN MOUNTAIN FALLS and PDO = 0.9689158124160764
# The lift of GREEN MOUNTAIN FALLS and INJ = 1.114293997090726
# The lift of GREEN MOUNTAIN FALLS and FAT = 0.0
# The lift of GRAND LAKE and PDO = 1.176063330932617
# The lift of GRAND LAKE and INJ = 0.47290991918969805
# The lift of GRAND LAKE and FAT = 0.0
# The lift of LAS ANIMAS and PDO = 1.040892415624128
# The lift of LAS ANIMAS and INJ = 0.8685778849117454
# The lift of LAS ANIMAS and FAT = 1.2664001188541065
# The lift of RIDGWAY and PDO = 1.0695210082697317
# The lift of RIDGWAY and INJ = 0.8027934237951948
# The lift of RIDGWAY and FAT = 0.0
# The lift of SEVERANCE and PDO = 1.020671563886749
# The lift of SEVERANCE and INJ = 0.9142925104334162
# The lift of SEVERANCE and FAT = 2.2024349893114903
# The lift of EMPIRE and PDO = 1.1073323570469444
# The lift of EMPIRE and INJ = 0.6857193828250622
# The lift of EMPIRE and FAT = 0.0
# The lift of WELLINGTON and PDO = 1.1148396950608221
# The lift of WELLINGTON and INJ = 0.6624746579835348
# The lift of WELLINGTON and FAT = 0.0
# The lift of KEYSTONE and PDO = 1.0630390627650668
# The lift of KEYSTONE and INJ = 0.8228632593900747
# The lift of KEYSTONE and FAT = 0.0
# The lift of CASCADE and PDO = 0.9199376504697693
# The lift of CASCADE and INJ = 1.2659434759847301
# The lift of CASCADE and FAT = 0.0
# The lift of IGNACIO and PDO = 1.015000854389386
# The lift of IGNACIO and INJ = 0.9476122083355086
# The lift of IGNACIO and FAT = 1.3291663055028526
# The lift of PIERCE and PDO = 1.0279387163530127
# The lift of PIERCE and INJ = 0.9315433125170656
# The lift of PIERCE and FAT = 0.0
# The lift of SUGAR CITY and PDO = 1.0490517066760527
# The lift of SUGAR CITY and INJ = 0.6496288889921641
# The lift of SUGAR CITY and FAT = 11.9974748101968
# The lift of ORDWAY and PDO = 1.098814415838891
# The lift of ORDWAY and INJ = 0.7120932052414107
# The lift of ORDWAY and FAT = 0.0
# The lift of FOXFIELD and PDO = 1.0743479889646952
# The lift of FOXFIELD and INJ = 0.7878478015436884
# The lift of FOXFIELD and FAT = 0.0
# The lift of CREEDE and PDO = 1.262358887033517
# The lift of CREEDE and INJ = 0.20571581484751866
# The lift of CREEDE and FAT = 0.0
# The lift of CEDAREDGE and PDO = 1.0690336439460728
# The lift of CEDAREDGE and INJ = 0.7733677249906716
# The lift of CEDAREDGE and FAT = 1.7139249728852572
# The lift of DOLORES and PDO = 1.1366833351855383
# The lift of DOLORES and INJ = 0.5948409104024636
# The lift of DOLORES and FAT = 0.0
# The lift of SOUTH FORK and PDO = 1.0977033800291451
# The lift of SOUTH FORK and INJ = 0.7155332690348475
# The lift of SOUTH FORK and FAT = 0.0
# The lift of EADS and PDO = 1.0250733819520286
# The lift of EADS and INJ = 0.9404151535886568
# The lift of EADS and FAT = 0.0
# The lift of LAKESIDE and PDO = 1.033800267325556
# The lift of LAKESIDE and INJ = 0.9133943841952694
# The lift of LAKESIDE and FAT = 0.0
# The lift of COLUMBINE VALLEY and PDO = 1.063039062765067
# The lift of COLUMBINE VALLEY and INJ = 0.8228632593900748
# The lift of COLUMBINE VALLEY and FAT = 0.0
# The lift of JULESBURG and PDO = 0.9929485751102272
# The lift of JULESBURG and INJ = 0.9946698739880024
# The lift of JULESBURG and FAT = 2.504967268063069
# The lift of RAYMER and PDO = 0.9301591799194334
# The lift of RAYMER and INJ = 1.234294889085112
# The lift of RAYMER and FAT = 0.0
# The lift of COLORADO CITY and PDO = 1.1161910159033201
# The lift of COLORADO CITY and INJ = 0.6582906075120597
# The lift of COLORADO CITY and FAT = 0.0
# The lift of LYONS and PDO = 1.0418281894469845
# The lift of LYONS and INJ = 0.8692217528768394
# The lift of LYONS and FAT = 1.070197283538682
# The lift of HOT SULPHUR SPRINGS and PDO = 1.008054283656529
# The lift of HOT SULPHUR SPRINGS and INJ = 0.9931108302983658
# The lift of HOT SULPHUR SPRINGS and FAT = 0.0
# The lift of YAMPA and PDO = 1.3287988284563335
# The lift of YAMPA and INJ = 0.0
# The lift of YAMPA and FAT = 0.0
# The lift of CARR and PDO = 0.5315195313825334
# The lift of CARR and INJ = 2.468589778170224
# The lift of CARR and FAT = 0.0
# The lift of SOMERSET and PDO = 0.9441465360084473
# The lift of SOMERSET and INJ = 1.1909862964856341
# The lift of SOMERSET and FAT = 0.0
# The lift of BLANCA and PDO = 1.0453217450523156
# The lift of BLANCA and INJ = 0.8777208100160796
# The lift of BLANCA and FAT = 0.0
# The lift of WALDEN and PDO = 1.1203597965416145
# The lift of WALDEN and INJ = 0.645382948541235
# The lift of WALDEN and FAT = 0.0
# The lift of HOTCHKISS and PDO = 1.1073323570469447
# The lift of HOTCHKISS and INJ = 0.6329717379923651
# The lift of HOTCHKISS and FAT = 2.9224618127402464
# The lift of DINOSAUR and PDO = 0.99659912134225
# The lift of DINOSAUR and INJ = 1.0285790742375933
# The lift of DINOSAUR and FAT = 0.0
# The lift of GILCREST and PDO = 1.0080542836565287
# The lift of GILCREST and INJ = 0.9458198383793961
# The lift of GILCREST and FAT = 2.6201381769395313
# The lift of SILVER PLUME and PDO = 1.0195094459708076
# The lift of SILVER PLUME and INJ = 0.9576425863591383
# The lift of SILVER PLUME and FAT = 0.0
# The lift of BRIGGSDALE and PDO = 1.039929517922348
# The lift of BRIGGSDALE and INJ = 0.8944165862935592
# The lift of BRIGGSDALE and FAT = 0.0
# The lift of OURAY and PDO = 1.1651062191537416
# The lift of OURAY and INJ = 0.5068360655663502
# The lift of OURAY and FAT = 0.0
# The lift of BENNETT and PDO = 0.9937104282369104
# The lift of BENNETT and INJ = 0.9301932497453018
# The lift of BENNETT and FAT = 5.946574471141023
# The lift of SILVERTON and PDO = 1.1681747942473262
# The lift of SILVERTON and INJ = 0.4973349369940012
# The lift of SILVERTON and FAT = 0.0
# The lift of MOUNTAIN VIEW and PDO = 0.9949626695830674
# The lift of MOUNTAIN VIEW and INJ = 1.0336459662289115
# The lift of MOUNTAIN VIEW and FAT = 0.0
# The lift of PALMER LAKE and PDO = 1.0011498022616212
# The lift of PALMER LAKE and INJ = 1.0144889499329688
# The lift of PALMER LAKE and FAT = 0.0
# The lift of FOWLER and PDO = 1.098814415838891
# The lift of FOWLER and INJ = 0.7120932052414107
# The lift of FOWLER and FAT = 0.0
# The lift of TIMNATH and PDO = 1.0157792430001071
# The lift of TIMNATH and INJ = 0.9596904064480083
# The lift of TIMNATH and FAT = 0.5264480863596749
# The lift of MANCOS and PDO = 1.0883495166404256
# The lift of MANCOS and INJ = 0.7444953299243533
# The lift of MANCOS and FAT = 0.0
# The lift of SAGUACHE and PDO = 0.99659912134225
# The lift of SAGUACHE and INJ = 0.9142925104334163
# The lift of SAGUACHE and FAT = 6.332000594270533
# The lift of STRASBURG and PDO = 1.102620304463766
# The lift of STRASBURG and INJ = 0.7003091569277231
# The lift of STRASBURG and FAT = 0.0
# The lift of KREMMLING and PDO = 1.1294790041878835
# The lift of KREMMLING and INJ = 0.5142895371187967
# The lift of KREMMLING and FAT = 5.698800534843481
# The lift of DEER TRAIL and PDO = 0.8528111884122738
# The lift of DEER TRAIL and INJ = 1.3509695303419134
# The lift of DEER TRAIL and FAT = 6.804537952051916
# The lift of EVERGREEN and PDO = 1.0089028141983274
# The lift of EVERGREEN and INJ = 0.9904835529695344
# The lift of EVERGREEN and FAT = 0.0
# The lift of SIMLA and PDO = 0.870592335885184
# The lift of SIMLA and INJ = 1.1349838060552753
# The lift of SIMLA and FAT = 15.720829061637186
# The lift of KIT CARSON and PDO = 1.2338846264237384
# The lift of KIT CARSON and INJ = 0.29387973549645524
# The lift of KIT CARSON and FAT = 0.0
# The lift of OLATHE and PDO = 0.9047140959702695
# The lift of OLATHE and INJ = 1.3130796692394806
# The lift of OLATHE and FAT = 0.0
# The lift of CHEYENNE WELLS and PDO = 1.0538749329136436
# The lift of CHEYENNE WELLS and INJ = 0.8512378545414564
# The lift of CHEYENNE WELLS and FAT = 0.0
# The lift of BOW MAR and PDO = 1.1932071112669118
# The lift of BOW MAR and INJ = 0.3358625548530917
# The lift of BOW MAR and FAT = 4.6520820692599845
# The lift of EL JEBEL and PDO = 0.9301591799194334
# The lift of EL JEBEL and INJ = 1.234294889085112
# The lift of EL JEBEL and FAT = 0.0
# The lift of ARAPAHOE and PDO = 0.759313616260762
# The lift of ARAPAHOE and INJ = 1.7632784129787316
# The lift of ARAPAHOE and FAT = 0.0
# The lift of BOONE and PDO = 1.1189884871211229
# The lift of BOONE and INJ = 0.6496288889921641
# The lift of BOONE and FAT = 0.0
# The lift of LA SALLE and PDO = 1.051669661024264
# The lift of LA SALLE and INJ = 0.858065965674142
# The lift of LA SALLE and FAT = 0.0
# The lift of NIWOT and PDO = 1.172469554520294
# The lift of NIWOT and INJ = 0.4840372114059263
# The lift of NIWOT and FAT = 0.0
# The lift of SNOWMASS and PDO = 1.1985244335096341
# The lift of SNOWMASS and INJ = 0.4033643428382718
# The lift of SNOWMASS and FAT = 0.0
# The lift of DEL NORTE and PDO = 0.8858658856375557
# The lift of DEL NORTE and INJ = 1.3714387656501246
# The lift of DEL NORTE and FAT = 0.0
# The lift of SPRINGFIELD and PDO = 1.0047015532230814
# The lift of SPRINGFIELD and INJ = 0.903142601769594
# The lift of SPRINGFIELD and FAT = 5.559805399847298
# The lift of AIR FORCE ACADEMY and PDO = 1.3287988284563335
# The lift of AIR FORCE ACADEMY and INJ = 0.0
# The lift of AIR FORCE ACADEMY and FAT = 0.0
# The lift of BATTLEMENT MESA and PDO = 1.138970424391143
# The lift of BATTLEMENT MESA and INJ = 0.5877594709929105
# The lift of BATTLEMENT MESA and FAT = 0.0
# The lift of OLNEY SPRINGS and PDO = 0.8304992677852083
# The lift of OLNEY SPRINGS and INJ = 1.5428686113563899
# The lift of OLNEY SPRINGS and FAT = 0.0
# The lift of MATHESON and PDO = 1.0335101999104817
# The lift of MATHESON and INJ = 0.9142925104334163
# The lift of MATHESON and FAT = 0.0
# The lift of REDSTONE and PDO = 0.8858658856375556
# The lift of REDSTONE and INJ = 1.3714387656501243
# The lift of REDSTONE and FAT = 0.0
# The lift of JEFFERSON and PDO = 1.0519657391945973
# The lift of JEFFERSON and INJ = 0.8571492285313277
# The lift of JEFFERSON and FAT = 0.0
# The lift of KEENESBURG and PDO = 1.0673957802354153
# The lift of KEENESBURG and INJ = 0.8093736977607292
# The lift of KEENESBURG and FAT = 0.0
# The lift of BETHUNE and PDO = 0.498299560671125
# The lift of BETHUNE and INJ = 2.314302917034585
# The lift of BETHUNE and FAT = 14.247001337108701
# The lift of EDWARDS and PDO = 0.9764658057595784
# The lift of EDWARDS and INJ = 1.059748137093278
# The lift of EDWARDS and FAT = 1.726909252982873
# The lift of CIMARRON and PDO = 0.0
# The lift of CIMARRON and INJ = 4.114316296950373
# The lift of CIMARRON and FAT = 0.0
# The lift of GENOA and PDO = 0.9491420203259525
# The lift of GENOA and INJ = 1.175518941985821
# The lift of GENOA and FAT = 0.0
# The lift of PONCHA SPRINGS and PDO = 1.0033787072017213
# The lift of PONCHA SPRINGS and INJ = 1.007587664559275
# The lift of PONCHA SPRINGS and FAT = 0.0
# The lift of PALISADE and PDO = 1.0261279841968352
# The lift of PALISADE and INJ = 0.8914351976725806
# The lift of PALISADE and FAT = 2.532800237708213
# The lift of GALETON and PDO = 1.3287988284563335
# The lift of GALETON and INJ = 0.0
# The lift of GALETON and FAT = 0.0
# The lift of NUNN and PDO = 0.944923611346726
# The lift of NUNN and INJ = 1.0971510125200994
# The lift of NUNN and FAT = 5.065600475416426
# The lift of BEULAH and PDO = 0.8858658856375557
# The lift of BEULAH and INJ = 1.3714387656501246
# The lift of BEULAH and FAT = 0.0
# The lift of PAONIA and PDO = 1.1124827401029769
# The lift of PAONIA and INJ = 0.5740906460860986
# The lift of PAONIA and FAT = 5.3012097998544
# The lift of NEDERLAND and PDO = 1.0766947028994007
# The lift of NEDERLAND and INJ = 0.7643196282872234
# The lift of NEDERLAND and FAT = 0.900996131991064
# The lift of HILLROSE and PDO = 1.3287988284563335
# The lift of HILLROSE and INJ = 0.0
# The lift of HILLROSE and FAT = 0.0
# The lift of RICO and PDO = 1.1811545141834077
# The lift of RICO and INJ = 0.45714625521670815
# The lift of RICO and FAT = 0.0
# The lift of GRANADA and PDO = 1.0630390627650668
# The lift of GRANADA and INJ = 0.8228632593900747
# The lift of GRANADA and FAT = 0.0
# The lift of ADAMS CITY and PDO = 1.0796490481207708
# The lift of ADAMS CITY and INJ = 0.7714343056781949
# The lift of ADAMS CITY and FAT = 0.0
# The lift of GILL and PDO = 1.1475989882122881
# The lift of GILL and INJ = 0.5610431314023235
# The lift of GILL and FAT = 0.0
# The lift of HASWELL and PDO = 0.6643994142281667
# The lift of HASWELL and INJ = 2.0571581484751866
# The lift of HASWELL and FAT = 0.0
# The lift of SANFORD and PDO = 1.0335101999104817
# The lift of SANFORD and INJ = 0.9142925104334163
# The lift of SANFORD and FAT = 0.0
# The lift of ARRIBA and PDO = 0.7751326499328611
# The lift of ARRIBA and INJ = 1.7142984570626554
# The lift of ARRIBA and FAT = 0.0
# The lift of GROVER and PDO = 1.0630390627650668
# The lift of GROVER and INJ = 0.5485755062600497
# The lift of GROVER and FAT = 15.19680142624928
# The lift of AVONDALE and PDO = 0.9965991213422499
# The lift of AVONDALE and INJ = 0.9494576069885475
# The lift of AVONDALE and FAT = 4.3836927191103685
# The lift of MARBLE and PDO = 1.3287988284563335
# The lift of MARBLE and INJ = 0.0
# The lift of MARBLE and FAT = 0.0
# The lift of WALSH and PDO = 0.9491420203259525
# The lift of WALSH and INJ = 1.175518941985821
# The lift of WALSH and FAT = 0.0
# The lift of WATKINS and PDO = 0.8304992677852083
# The lift of WATKINS and INJ = 1.5428686113563899
# The lift of WATKINS and FAT = 0.0
# The lift of COLLBRAN and PDO = 1.1864275254074406
# The lift of COLLBRAN and INJ = 0.4408196032446829
# The lift of COLLBRAN and FAT = 0.0
# The lift of ECKLEY and PDO = 1.3287988284563335
# The lift of ECKLEY and INJ = 0.0
# The lift of ECKLEY and FAT = 0.0
# The lift of ROGGEN and PDO = 1.0221529449664102
# The lift of ROGGEN and INJ = 0.9494576069885475
# The lift of ROGGEN and FAT = 0.0
# The lift of MEEKER and PDO = 1.1667501908397073
# The lift of MEEKER and INJ = 0.4013967118975974
# The lift of MEEKER and FAT = 5.559805399847298
# The lift of HOLLY and PDO = 0.8858658856375556
# The lift of HOLLY and INJ = 0.6857193828250622
# The lift of HOLLY and FAT = 37.9920035656232
# The lift of VERNON and PDO = 0.6643994142281667
# The lift of VERNON and INJ = 2.0571581484751866
# The lift of VERNON and FAT = 0.0
# The lift of OTIS and PDO = 1.2655226937679365
# The lift of OTIS and INJ = 0.1959198236643035
# The lift of OTIS and FAT = 0.0
# The lift of FLEMING and PDO = 1.2338846264237384
# The lift of FLEMING and INJ = 0.29387973549645524
# The lift of FLEMING and FAT = 0.0
# The lift of WILEY and PDO = 1.0335101999104817
# The lift of WILEY and INJ = 0.9142925104334163
# The lift of WILEY and FAT = 0.0
# The lift of KITTREDGE and PDO = 1.3287988284563335
# The lift of KITTREDGE and INJ = 0.0
# The lift of KITTREDGE and FAT = 0.0
# The lift of RYE and PDO = 0.9722918256997561
# The lift of RYE and INJ = 1.1038409577183927
# The lift of RYE and FAT = 0.0
# The lift of AMHERST and PDO = 1.3287988284563335
# The lift of AMHERST and INJ = 0.0
# The lift of AMHERST and FAT = 0.0
# The lift of PENROSE and PDO = 0.936199174594235
# The lift of PENROSE and INJ = 1.2155934513717013
# The lift of PENROSE and FAT = 0.0
# The lift of COAL CREEK and PDO = 0.8858658856375556
# The lift of COAL CREEK and INJ = 0.6857193828250622
# The lift of COAL CREEK and FAT = 37.9920035656232
# The lift of HAXTUN and PDO = 1.2482655661256468
# The lift of HAXTUN and INJ = 0.2493525028454772
# The lift of HAXTUN and FAT = 0.0
# The lift of SAW PIT and PDO = 1.1626989748992915
# The lift of SAW PIT and INJ = 0.5142895371187967
# The lift of SAW PIT and FAT = 0.0
# The lift of SEDALIA and PDO = 0.8177223559731283
# The lift of SEDALIA and INJ = 1.2659434759847301
# The lift of SEDALIA and FAT = 17.534770876441474
# The lift of WIGGINS and PDO = 1.1243682394630514
# The lift of WIGGINS and INJ = 0.6329717379923651
# The lift of WIGGINS and FAT = 0.0
# The lift of RED CLIFF and PDO = 0.8304992677852083
# The lift of RED CLIFF and INJ = 1.5428686113563899
# The lift of RED CLIFF and FAT = 0.0
# The lift of DOTSERO and PDO = 0.6643994142281667
# The lift of DOTSERO and INJ = 2.0571581484751866
# The lift of DOTSERO and FAT = 0.0
# The lift of CRESTONE and PDO = 1.2265835339596924
# The lift of CRESTONE and INJ = 0.31648586899618253
# The lift of CRESTONE and FAT = 0.0
# The lift of ALMA and PDO = 1.188925267566193
# The lift of ALMA and INJ = 0.4330859259947761
# The lift of ALMA and FAT = 0.0
# The lift of AGUILAR and PDO = 1.207998934960303
# The lift of AGUILAR and INJ = 0.37402875426821575
# The lift of AGUILAR and FAT = 0.0
# The lift of SAN LUIS and PDO = 1.016140280584255
# The lift of SAN LUIS and INJ = 0.9680744228118526
# The lift of SAN LUIS and FAT = 0.0
# The lift of DOVE CREEK and PDO = 1.0630390627650668
# The lift of DOVE CREEK and INJ = 0.8228632593900747
# The lift of DOVE CREEK and FAT = 0.0
# The lift of ANTON and PDO = 1.3287988284563335
# The lift of ANTON and INJ = 0.0
# The lift of ANTON and FAT = 0.0
# The lift of SECURITY and PDO = 1.138970424391143
# The lift of SECURITY and INJ = 0.5877594709929105
# The lift of SECURITY and FAT = 0.0
# The lift of WILLIAMSBURG and PDO = 1.1811545141834077
# The lift of WILLIAMSBURG and INJ = 0.45714625521670815
# The lift of WILLIAMSBURG and FAT = 0.0
# The lift of CRAWFORD and PDO = 0.9243817937087538
# The lift of CRAWFORD and INJ = 1.252183220810983
# The lift of CRAWFORD and FAT = 0.0
# The lift of RAMAH and PDO = 0.8542278182933573
# The lift of RAMAH and INJ = 1.4693986774822763
# The lift of RAMAH and FAT = 0.0
# The lift of CLIFTON and PDO = 0.8088340694951595
# The lift of CLIFTON and INJ = 1.6099498553284068
# The lift of CLIFTON and FAT = 0.0
# The lift of GARDNER and PDO = 0.6643994142281667
# The lift of GARDNER and INJ = 0.0
# The lift of GARDNER and FAT = 113.97601069686961
# The lift of BYERS and PDO = 0.9567351564885601
# The lift of BYERS and INJ = 1.1520085631461043
# The lift of BYERS and FAT = 0.0
# The lift of MERINO and PDO = 1.1073323570469444
# The lift of MERINO and INJ = 0.6857193828250622
# The lift of MERINO and FAT = 0.0
# The lift of SEIBERT and PDO = 0.99659912134225
# The lift of SEIBERT and INJ = 1.0285790742375933
# The lift of SEIBERT and FAT = 0.0
# The lift of CROWLEY and PDO = 1.1073323570469444
# The lift of CROWLEY and INJ = 0.6857193828250622
# The lift of CROWLEY and FAT = 0.0
# The lift of HUGO and PDO = 1.0630390627650668
# The lift of HUGO and INJ = 0.8228632593900747
# The lift of HUGO and FAT = 0.0
# The lift of AGATE and PDO = 0.7034817327121765
# The lift of AGATE and INJ = 1.9361488456237053
# The lift of AGATE and FAT = 0.0
# The lift of LA JARA and PDO = 0.7972792970738001
# The lift of LA JARA and INJ = 1.6457265187801493
# The lift of LA JARA and FAT = 0.0
# The lift of PEETZ and PDO = 1.138970424391143
# The lift of PEETZ and INJ = 0.5877594709929105
# The lift of PEETZ and FAT = 0.0
# The lift of SHERIDAN LAKE and PDO = 0.6643994142281667
# The lift of SHERIDAN LAKE and INJ = 2.0571581484751866
# The lift of SHERIDAN LAKE and FAT = 0.0
# The lift of OVID and PDO = 1.1811545141834077
# The lift of OVID and INJ = 0.45714625521670815
# The lift of OVID and FAT = 0.0
# The lift of PRITCHETT and PDO = 0.8858658856375556
# The lift of PRITCHETT and INJ = 1.3714387656501243
# The lift of PRITCHETT and FAT = 0.0
# The lift of VONA and PDO = 0.8858658856375556
# The lift of VONA and INJ = 1.3714387656501243
# The lift of VONA and FAT = 0.0
# The lift of WARD and PDO = 0.620106119946289
# The lift of WARD and INJ = 1.9200142719101738
# The lift of WARD and FAT = 15.19680142624928
# The lift of ANTONITO and PDO = 0.9301591799194334
# The lift of ANTONITO and INJ = 1.234294889085112
# The lift of ANTONITO and FAT = 0.0
# The lift of HAYDEN and PDO = 1.1197742936429775
# The lift of HAYDEN and INJ = 0.6471958219921935
# The lift of HAYDEN and FAT = 0.0
# The lift of LOG LANE VILLAGE and PDO = 1.3287988284563335
# The lift of LOG LANE VILLAGE and INJ = 0.0
# The lift of LOG LANE VILLAGE and FAT = 0.0
# The lift of HILLSIDE and PDO = 1.3287988284563335
# The lift of HILLSIDE and INJ = 0.0
# The lift of HILLSIDE and FAT = 0.0
# The lift of COKEDALE and PDO = 1.3287988284563335
# The lift of COKEDALE and INJ = 0.0
# The lift of COKEDALE and FAT = 0.0
# The lift of LIVERMORE and PDO = 0.7972792970738001
# The lift of LIVERMORE and INJ = 1.6457265187801493
# The lift of LIVERMORE and FAT = 0.0
# The lift of LAPORTE and PDO = 1.0630390627650668
# The lift of LAPORTE and INJ = 0.8228632593900747
# The lift of LAPORTE and FAT = 0.0
# The lift of NATURITA and PDO = 0.9491420203259525
# The lift of NATURITA and INJ = 0.5877594709929105
# The lift of NATURITA and FAT = 32.564574484819886
# The lift of VICTOR and PDO = 1.1959189456107002
# The lift of VICTOR and INJ = 0.4114316296950373
# The lift of VICTOR and FAT = 0.0
# The lift of MCCLAVE and PDO = 0.8858658856375556
# The lift of MCCLAVE and INJ = 1.3714387656501243
# The lift of MCCLAVE and FAT = 0.0
# The lift of DE BEQUE and PDO = 1.1243682394630514
# The lift of DE BEQUE and INJ = 0.6329717379923651
# The lift of DE BEQUE and FAT = 0.0
# The lift of WILD HORSE and PDO = 1.3287988284563335
# The lift of WILD HORSE and INJ = 0.0
# The lift of WILD HORSE and FAT = 0.0
# The lift of ILIFF and PDO = 1.0335101999104817
# The lift of ILIFF and INJ = 0.45714625521670815
# The lift of ILIFF and FAT = 25.328002377082132
# The lift of PHIPPSBURG and PDO = 1.3287988284563335
# The lift of PHIPPSBURG and INJ = 0.0
# The lift of PHIPPSBURG and FAT = 0.0
# The lift of EVANSTON and PDO = 1.3287988284563335
# The lift of EVANSTON and INJ = 0.0
# The lift of EVANSTON and FAT = 0.0
# The lift of TOWAOC and PDO = 1.1959189456107002
# The lift of TOWAOC and INJ = 0.4114316296950373
# The lift of TOWAOC and FAT = 0.0
# The lift of WOODY CREEK and PDO = 0.7972792970738001
# The lift of WOODY CREEK and INJ = 1.6457265187801493
# The lift of WOODY CREEK and FAT = 0.0
# The lift of BAILEY and PDO = 0.9135491945637292
# The lift of BAILEY and INJ = 1.2857238427969915
# The lift of BAILEY and FAT = 0.0
# The lift of CAPULIN and PDO = 0.4429329428187778
# The lift of CAPULIN and INJ = 0.0
# The lift of CAPULIN and FAT = 151.9680142624928
# The lift of MEREDITH and PDO = 1.3287988284563335
# The lift of MEREDITH and INJ = 0.0
# The lift of MEREDITH and FAT = 0.0
# The lift of ROCKVALE and PDO = 1.3287988284563335
# The lift of ROCKVALE and INJ = 0.0
# The lift of ROCKVALE and FAT = 0.0
# The lift of SEDGWICK and PDO = 1.1073323570469444
# The lift of SEDGWICK and INJ = 0.6857193828250622
# The lift of SEDGWICK and FAT = 0.0
# The lift of CHERAW and PDO = 1.3287988284563335
# The lift of CHERAW and INJ = 0.0
# The lift of CHERAW and FAT = 0.0
# The lift of WOLCOTT and PDO = 1.3287988284563335
# The lift of WOLCOTT and INJ = 0.0
# The lift of WOLCOTT and FAT = 0.0
# The lift of CAHONE and PDO = 1.3287988284563335
# The lift of CAHONE and INJ = 0.0
# The lift of CAHONE and FAT = 0.0
# The lift of STARKVILLE and PDO = 1.3287988284563335
# The lift of STARKVILLE and INJ = 0.0
# The lift of STARKVILLE and FAT = 0.0
# The lift of COPE and PDO = 1.3287988284563335
# The lift of COPE and INJ = 0.0
# The lift of COPE and FAT = 0.0
# The lift of SNYDER and PDO = 0.0
# The lift of SNYDER and INJ = 4.114316296950373
# The lift of SNYDER and FAT = 0.0
# The lift of CONIFER and PDO = 1.0630390627650668
# The lift of CONIFER and INJ = 0.8228632593900745
# The lift of CONIFER and FAT = 0.0
# The lift of RAND and PDO = 1.3287988284563335
# The lift of RAND and INJ = 0.0
# The lift of RAND and FAT = 0.0
# The lift of PADRONI and PDO = 1.3287988284563335
# The lift of PADRONI and INJ = 0.0
# The lift of PADRONI and FAT = 0.0
# The lift of COTOPAXI and PDO = 0.0
# The lift of COTOPAXI and INJ = 4.114316296950373
# The lift of COTOPAXI and FAT = 0.0
# The lift of CONEJOS and PDO = 0.0
# The lift of CONEJOS and INJ = 4.114316296950373
# The lift of CONEJOS and FAT = 0.0
# The lift of FORT GARLAND and PDO = 0.5315195313825334
# The lift of FORT GARLAND and INJ = 2.468589778170224
# The lift of FORT GARLAND and FAT = 0.0
# The lift of CUCHARA and PDO = 0.0
# The lift of CUCHARA and INJ = 4.114316296950373
# The lift of CUCHARA and FAT = 0.0
# The lift of HEENEY and PDO = 0.0
# The lift of HEENEY and INJ = 4.114316296950373
# The lift of HEENEY and FAT = 0.0
# The lift of NORWOOD and PDO = 0.99659912134225
# The lift of NORWOOD and INJ = 1.0285790742375933
# The lift of NORWOOD and FAT = 0.0
# The lift of LA VETA and PDO = 1.0796490481207708
# The lift of LA VETA and INJ = 0.7714343056781949
# The lift of LA VETA and FAT = 0.0
# The lift of NEW RAYMER and PDO = 0.6643994142281667
# The lift of NEW RAYMER and INJ = 2.0571581484751866
# The lift of NEW RAYMER and FAT = 0.0
# The lift of HOOPER and PDO = 0.6643994142281667
# The lift of HOOPER and INJ = 2.0571581484751866
# The lift of HOOPER and FAT = 0.0
# The lift of MONTEZUMA and PDO = 0.6643994142281667
# The lift of MONTEZUMA and INJ = 1.0285790742375933
# The lift of MONTEZUMA and FAT = 56.988005348434804
# The lift of HEREFORD and PDO = 1.3287988284563335
# The lift of HEREFORD and INJ = 0.0
# The lift of HEREFORD and FAT = 0.0
# The lift of COLUMBINE and PDO = 1.3287988284563335
# The lift of COLUMBINE and INJ = 0.0
# The lift of COLUMBINE and FAT = 0.0
# The lift of NUCLA and PDO = 0.99659912134225
# The lift of NUCLA and INJ = 0.0
# The lift of NUCLA and FAT = 56.988005348434804
# The lift of CHIPITA PARK and PDO = 0.4429329428187778
# The lift of CHIPITA PARK and INJ = 2.7428775313002487
# The lift of CHIPITA PARK and FAT = 0.0
# The lift of BELLVUE and PDO = 1.1073323570469444
# The lift of BELLVUE and INJ = 0.6857193828250622
# The lift of BELLVUE and FAT = 0.0
# The lift of HASTY and PDO = 1.3287988284563335
# The lift of HASTY and INJ = 0.0
# The lift of HASTY and FAT = 0.0
# The lift of TABERNASH and PDO = 1.2265835339596924
# The lift of TABERNASH and INJ = 0.31648586899618253
# The lift of TABERNASH and FAT = 0.0
# The lift of CHAMA and PDO = 0.4429329428187778
# The lift of CHAMA and INJ = 2.7428775313002487
# The lift of CHAMA and FAT = 0.0
# The lift of MASONVILLE and PDO = 0.6643994142281667
# The lift of MASONVILLE and INJ = 2.0571581484751866
# The lift of MASONVILLE and FAT = 0.0
# The lift of GUFFEY and PDO = 0.0
# The lift of GUFFEY and INJ = 4.114316296950373
# The lift of GUFFEY and FAT = 0.0
# The lift of WHITEWATER and PDO = 0.4429329428187778
# The lift of WHITEWATER and INJ = 1.3714387656501243
# The lift of WHITEWATER and FAT = 75.9840071312464
# The lift of ARBOLES and PDO = 1.3287988284563335
# The lift of ARBOLES and INJ = 0.0
# The lift of ARBOLES and FAT = 0.0
# The lift of COWDREY and PDO = 0.99659912134225
# The lift of COWDREY and INJ = 1.0285790742375933
# The lift of COWDREY and FAT = 0.0
# The lift of CLARK and PDO = 1.3287988284563335
# The lift of CLARK and INJ = 0.0
# The lift of CLARK and FAT = 0.0
# The lift of BLACK FOREST and PDO = 0.4429329428187778
# The lift of BLACK FOREST and INJ = 2.7428775313002487
# The lift of BLACK FOREST and FAT = 0.0
# The lift of UNKNOWN CITY NAME and PDO = 1.3287988284563335
# The lift of UNKNOWN CITY NAME and INJ = 0.0
# The lift of UNKNOWN CITY NAME and FAT = 0.0
# The lift of GLADE PARK and PDO = 1.3287988284563335
# The lift of GLADE PARK and INJ = 0.0
# The lift of GLADE PARK and FAT = 0.0
# The lift of MOLINA and PDO = 0.6643994142281667
# The lift of MOLINA and INJ = 2.0571581484751866
# The lift of MOLINA and FAT = 0.0
# The lift of WETMORE and PDO = 0.6643994142281667
# The lift of WETMORE and INJ = 2.0571581484751866
# The lift of WETMORE and FAT = 0.0
# The lift of VINELAND and PDO = 1.3287988284563335
# The lift of VINELAND and INJ = 0.0
# The lift of VINELAND and FAT = 0.0
# The lift of MESA and PDO = 0.8858658856375556
# The lift of MESA and INJ = 1.3714387656501243
# The lift of MESA and FAT = 0.0
# The lift of MACK and PDO = 1.3287988284563335
# The lift of MACK and INJ = 0.0
# The lift of MACK and FAT = 0.0
# The lift of WILLARD and PDO = 1.3287988284563335
# The lift of WILLARD and INJ = 0.0
# The lift of WILLARD and FAT = 0.0
# The lift of LOMA and PDO = 0.7972792970738001
# The lift of LOMA and INJ = 1.6457265187801493
# The lift of LOMA and FAT = 0.0
# The lift of CROOK and PDO = 1.3287988284563335
# The lift of CROOK and INJ = 0.0
# The lift of CROOK and FAT = 0.0
# The lift of GRAND VALLEY (PARACH and PDO = 1.3287988284563335
# The lift of GRAND VALLEY (PARACH and INJ = 0.0
# The lift of GRAND VALLEY (PARACH and FAT = 0.0
# The lift of PARSHALL and PDO = 1.3287988284563335
# The lift of PARSHALL and INJ = 0.0
# The lift of PARSHALL and FAT = 0.0
# The lift of TOPONAS and PDO = 1.3287988284563335
# The lift of TOPONAS and INJ = 0.0
# The lift of TOPONAS and FAT = 0.0
# The lift of HESPERUS and PDO = 0.8304992677852083
# The lift of HESPERUS and INJ = 1.5428686113563899
# The lift of HESPERUS and FAT = 0.0
# The lift of HYGIENE and PDO = 1.3287988284563335
# The lift of HYGIENE and INJ = 0.0
# The lift of HYGIENE and FAT = 0.0
# The lift of WESTON and PDO = 0.8858658856375556
# The lift of WESTON and INJ = 1.3714387656501243
# The lift of WESTON and FAT = 0.0
# The lift of GOLD HILL and PDO = 0.6643994142281667
# The lift of GOLD HILL and INJ = 2.0571581484751866
# The lift of GOLD HILL and FAT = 0.0
# The lift of BRISTOL and PDO = 0.0
# The lift of BRISTOL and INJ = 0.0
# The lift of BRISTOL and FAT = 227.95202139373922
# The lift of ORCHARD and PDO = 1.3287988284563335
# The lift of ORCHARD and INJ = 0.0
# The lift of ORCHARD and FAT = 0.0
# The lift of LAY and PDO = 1.3287988284563335
# The lift of LAY and INJ = 0.0
# The lift of LAY and FAT = 0.0
# The lift of ALMONT and PDO = 1.3287988284563335
# The lift of ALMONT and INJ = 0.0
# The lift of ALMONT and FAT = 0.0
# The lift of GOULD and PDO = 1.3287988284563335
# The lift of GOULD and INJ = 0.0
# The lift of GOULD and FAT = 0.0
# The lift of LAWSON and PDO = 0.0
# The lift of LAWSON and INJ = 4.114316296950373
# The lift of LAWSON and FAT = 0.0
# The lift of WESTCREEK and PDO = 0.6643994142281667
# The lift of WESTCREEK and INJ = 2.0571581484751866
# The lift of WESTCREEK and FAT = 0.0
# The lift of BOND and PDO = 0.0
# The lift of BOND and INJ = 4.114316296950373
# The lift of BOND and FAT = 0.0
# The lift of MARVEL and PDO = 0.0
# The lift of MARVEL and INJ = 4.114316296950373
# The lift of MARVEL and FAT = 0.0
# The lift of LUCERNE and PDO = 0.9301591799194334
# The lift of LUCERNE and INJ = 1.234294889085112
# The lift of LUCERNE and FAT = 0.0
# The lift of ARLINGTON and PDO = 1.3287988284563335
# The lift of ARLINGTON and INJ = 0.0
# The lift of ARLINGTON and FAT = 0.0
# The lift of WEST VILLAGE and PDO = 0.0
# The lift of WEST VILLAGE and INJ = 4.114316296950373
# The lift of WEST VILLAGE and FAT = 0.0
# The lift of CAMPION and PDO = 1.3287988284563335
# The lift of CAMPION and INJ = 0.0
# The lift of CAMPION and FAT = 0.0
# The lift of MAYBELL and PDO = 0.0
# The lift of MAYBELL and INJ = 0.0
# The lift of MAYBELL and FAT = 227.95202139373922
# The lift of ROLLINSVILLE and PDO = 0.6643994142281667
# The lift of ROLLINSVILLE and INJ = 2.0571581484751866
# The lift of ROLLINSVILLE and FAT = 0.0
# The lift of COMO and PDO = 1.3287988284563335
# The lift of COMO and INJ = 0.0
# The lift of COMO and FAT = 0.0
# The lift of PLATORO and PDO = 1.3287988284563335
# The lift of PLATORO and INJ = 0.0
# The lift of PLATORO and FAT = 0.0
# The lift of MONTBELLO and PDO = 0.0
# The lift of MONTBELLO and INJ = 4.114316296950373
# The lift of MONTBELLO and FAT = 0.0
# The lift of WAGON WHEEL GAP and PDO = 0.6643994142281667
# The lift of WAGON WHEEL GAP and INJ = 2.0571581484751866
# The lift of WAGON WHEEL GAP and FAT = 0.0
# The lift of AUSTIN and PDO = 0.7972792970738001
# The lift of AUSTIN and INJ = 1.6457265187801493
# The lift of AUSTIN and FAT = 0.0
# The lift of PAOLI and PDO = 0.6643994142281667
# The lift of PAOLI and INJ = 2.0571581484751866
# The lift of PAOLI and FAT = 0.0
# The lift of FALCON and PDO = 1.3287988284563335
# The lift of FALCON and INJ = 0.0
# The lift of FALCON and FAT = 0.0
# The lift of ECKERT and PDO = 1.3287988284563335
# The lift of ECKERT and INJ = 0.0
# The lift of ECKERT and FAT = 0.0
# The lift of FORT CARSON and PDO = 1.3287988284563335
# The lift of FORT CARSON and INJ = 0.0
# The lift of FORT CARSON and FAT = 0.0
# The lift of WELDONA and PDO = 1.3287988284563335
# The lift of WELDONA and INJ = 0.0
# The lift of WELDONA and FAT = 0.0
# The lift of LOUVIERS and PDO = 0.6643994142281667
# The lift of LOUVIERS and INJ = 2.0571581484751866
# The lift of LOUVIERS and FAT = 0.0
# The lift of DRAKE and PDO = 0.6643994142281667
# The lift of DRAKE and INJ = 2.0571581484751866
# The lift of DRAKE and FAT = 0.0
# The lift of KIRK and PDO = 1.3287988284563335
# The lift of KIRK and INJ = 0.0
# The lift of KIRK and FAT = 0.0
# The lift of BRANDON and PDO = 1.3287988284563335
# The lift of BRANDON and INJ = 0.0
# The lift of BRANDON and FAT = 0.0
# The lift of MASTERS and PDO = 1.3287988284563335
# The lift of MASTERS and INJ = 0.0
# The lift of MASTERS and FAT = 0.0
# The lift of GILPIN and PDO = 1.3287988284563335
# The lift of GILPIN and INJ = 0.0
# The lift of GILPIN and FAT = 0.0
# The lift of GLENDEVEY and PDO = 1.3287988284563335
# The lift of GLENDEVEY and INJ = 0.0
# The lift of GLENDEVEY and FAT = 0.0
# The lift of HARTSEL and PDO = 0.4429329428187778
# The lift of HARTSEL and INJ = 1.3714387656501243
# The lift of HARTSEL and FAT = 75.9840071312464
# The lift of KEOTA and PDO = 1.3287988284563335
# The lift of KEOTA and INJ = 0.0
# The lift of KEOTA and FAT = 0.0
# The lift of GATEWAY and PDO = 1.3287988284563335
# The lift of GATEWAY and INJ = 0.0
# The lift of GATEWAY and FAT = 0.0
# The lift of BLENDE and PDO = 1.138970424391143
# The lift of BLENDE and INJ = 0.5877594709929105
# The lift of BLENDE and FAT = 0.0
# The lift of HENDERSON and PDO = 0.99659912134225
# The lift of HENDERSON and INJ = 1.0285790742375933
# The lift of HENDERSON and FAT = 0.0
# The lift of PINE and PDO = 0.8858658856375556
# The lift of PINE and INJ = 1.3714387656501243
# The lift of PINE and FAT = 0.0
# The lift of YODER and PDO = 0.0
# The lift of YODER and INJ = 0.0
# The lift of YODER and FAT = 227.95202139373922
# The lift of RUSH and PDO = 0.6643994142281667
# The lift of RUSH and INJ = 2.0571581484751866
# The lift of RUSH and FAT = 0.0
# The lift of DIVIDE and PDO = 0.759313616260762
# The lift of DIVIDE and INJ = 1.175518941985821
# The lift of DIVIDE and FAT = 32.564574484819886
# The lift of DUMONT and PDO = 1.3287988284563335
# The lift of DUMONT and INJ = 0.0
# The lift of DUMONT and FAT = 0.0
# The lift of GLEN HAVEN and PDO = 0.6643994142281667
# The lift of GLEN HAVEN and INJ = 2.0571581484751866
# The lift of GLEN HAVEN and FAT = 0.0
# The lift of FORT LOGAN and PDO = 0.0
# The lift of FORT LOGAN and INJ = 4.114316296950373
# The lift of FORT LOGAN and FAT = 0.0
# The lift of JAMESTOWN and PDO = 1.3287988284563335
# The lift of JAMESTOWN and INJ = 0.0
# The lift of JAMESTOWN and FAT = 0.0
# The lift of COALMONT and PDO = 1.3287988284563335
# The lift of COALMONT and INJ = 0.0
# The lift of COALMONT and FAT = 0.0
# The lift of LAKE GEORGE and PDO = 1.3287988284563335
# The lift of LAKE GEORGE and INJ = 0.0
# The lift of LAKE GEORGE and FAT = 0.0
# The lift of FLORISSANT and PDO = 1.3287988284563335
# The lift of FLORISSANT and INJ = 0.0
# The lift of FLORISSANT and FAT = 0.0
# The lift of CAMPO and PDO = 1.3287988284563335
# The lift of CAMPO and INJ = 0.0
# The lift of CAMPO and FAT = 0.0
# The lift of HAMILTON and PDO = 1.3287988284563335
# The lift of HAMILTON and INJ = 0.0
# The lift of HAMILTON and FAT = 0.0
# The lift of PROSPECT VALLEY and PDO = 1.3287988284563335
# The lift of PROSPECT VALLEY and INJ = 0.0
# The lift of PROSPECT VALLEY and FAT = 0.0
# The lift of HOEHNE and PDO = 1.3287988284563335
# The lift of HOEHNE and INJ = 0.0
# The lift of HOEHNE and FAT = 0.0
# The lift of RED FEATHER and PDO = 1.3287988284563335
# The lift of RED FEATHER and INJ = 0.0
# The lift of RED FEATHER and FAT = 0.0
# The lift of BONCARBO and PDO = 1.3287988284563335
# The lift of BONCARBO and INJ = 0.0
# The lift of BONCARBO and FAT = 0.0
# The lift of COPPER MOUNTAIN and PDO = 0.8858658856375556
# The lift of COPPER MOUNTAIN and INJ = 1.3714387656501243
# The lift of COPPER MOUNTAIN and FAT = 0.0
# The lift of NATHROP and PDO = 1.3287988284563335
# The lift of NATHROP and INJ = 0.0
# The lift of NATHROP and FAT = 0.0
# The lift of ROCKPORT and PDO = 0.6643994142281667
# The lift of ROCKPORT and INJ = 2.0571581484751866
# The lift of ROCKPORT and FAT = 0.0
# The lift of CORY and PDO = 0.0
# The lift of CORY and INJ = 4.114316296950373
# The lift of CORY and FAT = 0.0
# The lift of VILAS and PDO = 1.3287988284563335
# The lift of VILAS and INJ = 0.0
# The lift of VILAS and FAT = 0.0
# The lift of FRUITVALE and PDO = 0.0
# The lift of FRUITVALE and INJ = 4.114316296950373
# The lift of FRUITVALE and FAT = 0.0
# The lift of LOOKOUT MOUNTAIN and PDO = 1.3287988284563335
# The lift of LOOKOUT MOUNTAIN and INJ = 0.0
# The lift of LOOKOUT MOUNTAIN and FAT = 0.0
# The lift of GRANT and PDO = 1.3287988284563335
# The lift of GRANT and INJ = 0.0
# The lift of GRANT and FAT = 0.0
# The lift of BONDAD and PDO = 1.3287988284563335
# The lift of BONDAD and INJ = 0.0
# The lift of BONDAD and FAT = 0.0
# The lift of PETERSON FIELD and PDO = 1.3287988284563335
# The lift of PETERSON FIELD and INJ = 0.0
# The lift of PETERSON FIELD and FAT = 0.0
# The lift of MOSCA and PDO = 0.0
# The lift of MOSCA and INJ = 4.114316296950373
# The lift of MOSCA and FAT = 0.0
# The lift of MILNER and PDO = 1.3287988284563335
# The lift of MILNER and INJ = 0.0
# The lift of MILNER and FAT = 0.0
# The lift of GARFIELD and PDO = 0.0
# The lift of GARFIELD and INJ = 4.114316296950373
# The lift of GARFIELD and FAT = 0.0
# The lift of ATWOOD and PDO = 1.3287988284563335
# The lift of ATWOOD and INJ = 0.0
# The lift of ATWOOD and FAT = 0.0
# The lift of KIM and PDO = 1.3287988284563335
# The lift of KIM and INJ = 0.0
# The lift of KIM and FAT = 0.0

# %%
columns = ['SYSTEM', 'DATE', 'TIME', 'SEVERITY', 'ROAD_DESC', 'VEHICLES', 'CONTOUR', 'CONDITION', 'LIGHTING', 
             'WEATHER', 'CITY', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'AGE_1', 'AGE_2']
df_all = df[columns]
print(len(df_all))
for i in columns:
    df_all = df_all[df_all[i] != "UNKOWN"]
    df_all = df_all[df_all[i] != 0]
    
df_all = df_all.dropna()
print(len(df_all))



df_all = create_labels(df_all, columns)
df_all.corr(method='pearson')
# Out:
# 1449091
# 453546
#              SYSTEM      DATE      TIME  SEVERITY  ROAD_DESC  VEHICLES  \
# SYSTEM     1.000000  0.007521 -0.004583  0.014081   0.102120  0.026260
# DATE       0.007521  1.000000  0.017140 -0.018361   0.002119  0.002621
# TIME      -0.004583  0.017140  1.000000 -0.022576  -0.035274 -0.001442
# SEVERITY   0.014081 -0.018361 -0.022576  1.000000   0.066554 -0.120670
# ROAD_DESC  0.102120  0.002119 -0.035274  0.066554   1.000000  0.105394
# VEHICLES   0.026260  0.002621 -0.001442 -0.120670   0.105394  1.000000
# CONTOUR   -0.004274  0.014976  0.017712 -0.012963  -0.140894  0.017445
# CONDITION -0.014670 -0.100984 -0.001722  0.015877  -0.012547 -0.009130
# LIGHTING  -0.006210  0.194670 -0.367608  0.051919   0.035232  0.013406
# WEATHER   -0.517414 -0.047904  0.006614  0.006577  -0.085481 -0.019842
# CITY       0.183329 -0.000807 -0.000702  0.029645   0.035378  0.000355
# COUNTY     0.217270  0.001119  0.002053  0.002318  -0.044558 -0.025751
# LATITUDE   0.200653 -0.004545 -0.009929  0.011861   0.051559  0.013237
# LONGITUDE -0.325183  0.000844 -0.002344 -0.045228  -0.023302  0.002102
# AGE_1      0.016372 -0.002546 -0.048435 -0.007802  -0.057233 -0.017714
# AGE_2      0.020628  0.006461 -0.061260 -0.005335   0.000608 -0.027686
#
#             CONTOUR  CONDITION  LIGHTING   WEATHER      CITY    COUNTY  \
# SYSTEM    -0.004274  -0.014670 -0.006210 -0.517414  0.183329  0.217270
# DATE       0.014976  -0.100984  0.194670 -0.047904 -0.000807  0.001119
# TIME       0.017712  -0.001722 -0.367608  0.006614 -0.000702  0.002053
# SEVERITY  -0.012963   0.015877  0.051919  0.006577  0.029645  0.002318
# ROAD_DESC -0.140894  -0.012547  0.035232 -0.085481  0.035378 -0.044558
# VEHICLES   0.017445  -0.009130  0.013406 -0.019842  0.000355 -0.025751
# CONTOUR    1.000000  -0.021204 -0.005125 -0.000475 -0.024493  0.015780
# CONDITION -0.021204   1.000000 -0.061277  0.212061 -0.004028  0.007905
# LIGHTING  -0.005125  -0.061277  1.000000 -0.023577  0.017943  0.028121
# WEATHER   -0.000475   0.212061 -0.023577  1.000000 -0.104780 -0.081854
# CITY      -0.024493  -0.004028  0.017943 -0.104780  1.000000  0.280011
# COUNTY     0.015780   0.007905  0.028121 -0.081854  0.280011  1.000000
# LATITUDE   0.054888   0.005940 -0.013277 -0.125728  0.146102  0.043405
# LONGITUDE  0.002912  -0.021322 -0.026123  0.169089 -0.230141 -0.043273
# AGE_1     -0.002924  -0.023931  0.075940 -0.018184  0.018247  0.024400
# AGE_2     -0.001321  -0.010668  0.102664 -0.008620  0.024165  0.017282
#
#            LATITUDE  LONGITUDE     AGE_1     AGE_2
# SYSTEM     0.200653  -0.325183  0.016372  0.020628
# DATE      -0.004545   0.000844 -0.002546  0.006461
# TIME      -0.009929  -0.002344 -0.048435 -0.061260
# SEVERITY   0.011861  -0.045228 -0.007802 -0.005335
# ROAD_DESC  0.051559  -0.023302 -0.057233  0.000608
# VEHICLES   0.013237   0.002102 -0.017714 -0.027686
# CONTOUR    0.054888   0.002912 -0.002924 -0.001321
# CONDITION  0.005940  -0.021322 -0.023931 -0.010668
# LIGHTING  -0.013277  -0.026123  0.075940  0.102664
# WEATHER   -0.125728   0.169089 -0.018184 -0.008620
# CITY       0.146102  -0.230141  0.018247  0.024165
# COUNTY     0.043405  -0.043273  0.024400  0.017282
# LATITUDE   1.000000  -0.322311 -0.028162 -0.025459
# LONGITUDE -0.322311   1.000000 -0.025896 -0.025345
# AGE_1     -0.028162  -0.025896  1.000000  0.036489
# AGE_2     -0.025459  -0.025345  0.036489  1.000000
